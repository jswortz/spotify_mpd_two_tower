# %% [markdown]
# # Two-Tower for Neural Deep Retrieval
#
# > model baseline for spotify modeling experiments

# %%
# set variables
SEED = 41781897
PROJECT_ID = 'hybrid-vertex'
BQ_LOCATION='us-central1'

# %% [markdown]
# ### Pip

# %%
# !pip freeze | grep tensorflow
# Out:
# tensorflow==2.9.1
# tensorflow-cloud==0.1.16
# tensorflow-data-validation==1.9.0
# tensorflow-datasets==4.4.0
# tensorflow-estimator==2.9.0
# tensorflow-hub==0.12.0
# tensorflow-io==0.23.1
# tensorflow-io-gcs-filesystem==0.26.0
# tensorflow-metadata==1.9.0
# tensorflow-probability==0.14.1
# tensorflow-recommenders==0.6.0
# tensorflow-serving-api==2.9.0
# tensorflow-transform==1.9.0

# %% [markdown]
# ### Import Package

# %%
import warnings
warnings.filterwarnings("ignore") #do this b/c there's an info-level bug that can safely be ignored

# from tensorflow.python.framework import ops
# from tensorflow.python.framework import dtypes
# from tensorflow_io.bigquery import BigQueryClient
# from tensorflow_io.bigquery import BigQueryReadSession

import json
import tensorflow as tf
import tensorflow_recommenders as tfrs
import datetime
from tensorflow.python.lib.io import file_io
from tensorflow.train import BytesList, Feature, FeatureList, Int64List, FloatList
from tensorflow.train import SequenceExample, FeatureLists

import os
import numpy as np
import pickle as pkl

from pprint import pprint
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method __contains__ of dict object at 0x7efd509d0c80> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1970/2579538069.py in <module>
#       8
#       9 import json
# ---> 10 import tensorflow as tf
#      11 import tensorflow_recommenders as tfrs
#      12 import datetime
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      35
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      38
#      39 # pylint: enable=wildcard-import
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/context.py in <module>
#      33 from tensorflow.python import pywrap_tfe
#      34 from tensorflow.python import tf2
# ---> 35 from tensorflow.python.client import pywrap_tf_session
#      36 from tensorflow.python.eager import executor
#      37 from tensorflow.python.eager import monitoring
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/client/pywrap_tf_session.py in <module>
#      17 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
#      18 from tensorflow.python import pywrap_tensorflow
# ---> 19 from tensorflow.python.client._pywrap_tf_session import *
#      20 from tensorflow.python.client._pywrap_tf_session import _TF_SetTarget
#      21 from tensorflow.python.client._pywrap_tf_session import _TF_SetConfig
#
# ImportError: initialization failed

# %%
import tensorflow as tf
print(tf. __version__)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xe but this version of numpy is 0xd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.multiarray failed to import
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method __contains__ of dict object at 0x7efcb15be5a0> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1970/3641963133.py in <module>
# ----> 1 import tensorflow as tf
#       2 print(tf. __version__)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>
#      35
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      38
#      39 # pylint: enable=wildcard-import
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/context.py in <module>
#      33 from tensorflow.python import pywrap_tfe
#      34 from tensorflow.python import tf2
# ---> 35 from tensorflow.python.client import pywrap_tf_session
#      36 from tensorflow.python.eager import executor
#      37 from tensorflow.python.eager import monitoring
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/client/pywrap_tf_session.py in <module>
#      17 # pylint: disable=invalid-import-order,g-bad-import-order, wildcard-import, unused-import
#      18 from tensorflow.python import pywrap_tensorflow
# ---> 19 from tensorflow.python.client._pywrap_tf_session import *
#      20 from tensorflow.python.client._pywrap_tf_session import _TF_SetTarget
#      21 from tensorflow.python.client._pywrap_tf_session import _TF_SetConfig
#
# ImportError: initialization failed

# %% [markdown]
# ## TF-Record reader

# %%
# for raw_record in raw_test_ds.take(5):
#     example = tf.train.Example()
#     example.ParseFromString(raw_record.numpy())
#     print(example)

# %% [markdown]
# ### train (query & candidate features)

# %%
from google.cloud import storage

client = storage.Client()

# =========================
# all training data
# =========================
train_files = []

BUCKET_NAME_TRAIN = 'spotify-tfrecords-blog'
OBJ_PATH_TRAIN = 'train_v2'

for blob in client.list_blobs(f'{BUCKET_NAME_TRAIN}', prefix=f'{OBJ_PATH_TRAIN}/', delimiter='/'):
    train_files.append(blob.public_url.replace("https://storage.googleapis.com/", "gs://"))

# =========================
# all candidate data
# =========================
candidate_files = []

BUCKET_NAME_CANDIDATE = 'spotify-tfrecords-blog'
OBJ_PATH_CANDIDATE = 'candidate_tracks_v2'

for blob in client.list_blobs(f'{BUCKET_NAME_CANDIDATE}', prefix=f'{OBJ_PATH_CANDIDATE}/', delimiter='/'):
    candidate_files.append(blob.public_url.replace("https://storage.googleapis.com/", "gs://"))
    
print(f"Length of train_files: {len(train_files)}")
print(f"Length of candidate_files: {len(candidate_files)}")

print(f"Example of train_files: {train_files[0]}")
print(f"Example of candidate_files: {candidate_files[0]}")
# Out:
# Length of train_files: 1890
# Length of candidate_files: 184
# Example of train_files: gs://spotify-tfrecords-blog/train_v2/spotify-000000-5343.tfrec
# Example of candidate_files: gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000000-12227.tfrec

# %% [markdown]
# ### parsing function - train data

# %%
# =========================
# Training Data TF Reocrds
# =========================

train_context_features = {
    # playlist - context features
    # 'pid': tf.io.FixedLenFeature(dtype=tf.int64, shape=(1)),
    'name': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'collaborative': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    # 'duration_ms_seed_pl': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'n_songs_pl': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'num_artists_pl': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'num_albums_pl': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'description_pl': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    # seed track - context features
    # 'pos_seed_track': tf.io.FixedLenFeature(dtype=tf.int64, shape=(1)),
    'track_name_seed_track': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'artist_name_seed_track': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'album_name_seed_track': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    # 'track_uri_seed_track': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    # 'artist_uri_seed_track': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    # 'album_uri_seed_track': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'duration_seed_track': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'track_pop_seed_track': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'artist_pop_seed_track': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'artist_genres_seed_track': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'artist_followers_seed_track': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    # candidate - context features
    'track_name_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'artist_name_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'album_name_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'track_uri_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    # 'artist_uri_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    # 'album_uri_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'duration_ms_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'track_pop_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'artist_pop_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'artist_genres_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'artist_followers_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
}

# Sequence tracks - ragged
train_sequence_features = {
    'track_name_pl': tf.io.RaggedFeature(tf.string),
    'artist_name_pl': tf.io.RaggedFeature(tf.string),
    'album_name_pl': tf.io.RaggedFeature(tf.string),
    # 'track_uri_pl': tf.io.RaggedFeature(tf.string),
    'duration_ms_songs_pl': tf.io.RaggedFeature(tf.float32),
    'artist_pop_pl': tf.io.RaggedFeature(tf.float32),
    'artists_followers_pl': tf.io.RaggedFeature(tf.float32),
    'track_pop_pl': tf.io.RaggedFeature(tf.float32),
    'artist_genres_pl': tf.io.RaggedFeature(tf.string),
}

# parse_sequence_example | parse_single_sequence_example
def parse_train_tfrecord_fn(example):
    example = tf.io.parse_single_sequence_example( 
        example, 
        sequence_features=train_sequence_features, 
        context_features=train_context_features
    )
    return example

# TF data input pipeline params
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.DATA

# parse training data - SAMPLE_FILE_TRAIN | train_files
raw_train_ds = tf.data.TFRecordDataset(train_files)

parsed_train_ds = raw_train_ds.map(
    parse_train_tfrecord_fn, 
    num_parallel_calls=tf.data.AUTOTUNE
).with_options(options)

# %%
for _ in parsed_train_ds.batch(2).take(1):
    print(_)
# Out:
# ({'album_name_can': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'Zappruder Collection #2'],
#        [b'Music for Thanksgiving Dinner']], dtype=object)>, 'album_name_seed_track': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'ZABA'],
#        [b'100 World Classical Masterpieces']], dtype=object)>, 'artist_followers_can': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[0.],
#        [0.]], dtype=float32)>, 'artist_followers_seed_track': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[2604423.],
#        [   3468.]], dtype=float32)>, 'artist_genres_can': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'NONE'],
#        [b'NONE']], dtype=object)>, 'artist_genres_seed_track': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b"'gauze pop', 'indietronica', 'shiver pop'"],
#        [b"'balkan classical piano'"]], dtype=object)>, 'artist_name_can': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'Modern Pleasure'],
#        [b'Ferdinand Land']], dtype=object)>, 'artist_name_seed_track': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'Glass Animals'],
#        [b'Dubravka Tom\xc5\xa1i\xc4\x8d']], dtype=object)>, 'artist_pop_can': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[0.],
#        [0.]], dtype=float32)>, 'artist_pop_seed_track': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[87.],
#        [31.]], dtype=float32)>, 'collaborative': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'false'],
#        [b'false']], dtype=object)>, 'description_pl': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'NONE'],
#        [b'NONE']], dtype=object)>, 'duration_ms_can': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[290013.],
#        [184026.]], dtype=float32)>, 'duration_seed_track': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[289306.],
#        [148533.]], dtype=float32)>, 'n_songs_pl': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[  4.],
#        [109.]], dtype=float32)>, 'name': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'FUN'],
#        [b'Classical']], dtype=object)>, 'num_albums_pl': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[ 4.],
#        [50.]], dtype=float32)>, 'num_artists_pl': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[ 4.],
#        [52.]], dtype=float32)>, 'track_name_can': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'Kalifornia'],
#        [b"Eine kline Nachtmusik' Serenade No.13 In G Major 4th Movement"]],
#       dtype=object)>, 'track_name_seed_track': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'Gooey'],
#        [b'The Girl with the Flaxen Hair']], dtype=object)>, 'track_pop_can': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[0.],
#        [0.]], dtype=float32)>, 'track_pop_seed_track': <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
# array([[40.],
#        [30.]], dtype=float32)>, 'track_uri_can': <tf.Tensor: shape=(2, 1), dtype=string, numpy=
# array([[b'spotify:track:3HBlI15YYm1VRrckzlMxgJ'],
#        [b'spotify:track:55kjKDiHR1KWZPOiEVX19h']], dtype=object)>}, {'album_name_pl': <tf.RaggedTensor [[[b'Colors', b'THIS IS... ICONA POP', b'Brazilian Girls', b'ZABA']],
#  [[b'The 50 Greatest Pieces of Classical Music',
#  b'Tchaikovsky / Rachmaninov: Piano Concertos',
#  b'50 French World Classical Masters',
#  b'Music For The Millions Vol. 40 - Pjotr I. Tchaikovsky',
#  b'Tchaikovsky: The Nutcracker / Swan Lake (Excerpts)',
#  b'Ravel: Bol\xc3\xa9ro; Pavane pour une infante d\xc3\xa9funte; Daphnis et Chlo\xc3\xab (2e Suite)',
#  b'Schubert: Lieder (Vol. 3)', b'Romanza',
#  b'Gershwin: Rhapsody in Blue/An American in Paris', b'Copland Super Hits',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Conducts Copland - Expanded Edition (Fanfare for the Common Man, Appalachian Spring, Old American Songs (Complete), Rodeo: Four Dance Episodes)',
#  b'Copland Super Hits', b'Thanksgiving Playlist',
#  b"Classical Piano's Greatest Moments",
#  b'Thanksgiving - Atkins Dieting Meditations',
#  b"Classical Piano's Greatest Moments", b'World Classical 2010',
#  b'100 World Classical Masterpieces',
#  b"Classical Piano's Greatest Moments",
#  b'Frederic Chopin: Polonaise - Valse No. 3 - Nocturne No. 1 - Prelude No. 6 - Mazurka No. 3',
#  b"Classical Piano's Greatest Moments", b'World Classical 2010',
#  b'Kids Orchestral Music for Play & Relaxation', b'Classic Love Music',
#  b'Chopin: Etudes, Op. 10 - Fantasy, Op. 49 - Impromptu No. 4 - Nocturnes',
#  b'100 World Classical Masterpieces',
#  b'Requiem, Finished by Franz Xaver Suessmayr (Vollendet von Franz Xaver Suessmayr)',
#  b'Bizet: Carmen, Opera Suite', b'Russian Composers',
#  b'Requiem, Finished by Franz Xaver Suessmayr (Vollendet von Franz Xaver Suessmayr)',
#  b'World Classical 2010', b'Thanksgiving Classical Moods',
#  b"Classical Piano's Greatest Moments",
#  b'100 World Classical Masterpieces', b'World Classical 2010',
#  b'Haydn: Great Symphonies',
#  b'Don Giovanni Highlights - Overture and Arias', b'World Classical 2010',
#  b'World Classical 2010', b'World Classical 2010',
#  b"Classical Piano's Greatest Moments",
#  b'Beethoven, L. Van: Symphonies Nos. 1-9',
#  b'Liszt: Les Pr\xc3\xa9ludes - Tasso - Orpheus', b'World Classical 2010',
#  b'Symphonic Superstars', b'100 World Classical Masterpieces',
#  b'World Classical 2010', b'Geschichten aus dem Wienerwald',
#  b'Brahms: Hungarian Dances 1- 21',
#  b'Pontinen, Roland: Music for A Rainy Day',
#  b'Mama Mia - The Italian Classical Wedding',
#  b'Hallelujah Classical Collection', b'World Classical 2010',
#  b'H\xc3\xa4ndel: Konzerte', b'Mama Mia - The Italian Classical Wedding',
#  b'Mama Mia - The Italian Classical Wedding',
#  b'Fr\xc3\xa9d\xc3\xa9ric Chopin: Walzer', b'Soundtrack For Thanksgiving',
#  b'100 World Classical Masterpieces', b'Movie Themes',
#  b"You're My Valentine", b'150 Classical Essential Masters',
#  b'100 World Classical Masterpieces',
#  b'Requiem, Finished by Franz Xaver Suessmayr (Vollendet von Franz Xaver Suessmayr)',
#  b'World Classical 2010', b'World Classical 2010', b'World Classical 2010',
#  b'The Wonders Of Opera (Vol. 1)', b'Christmas Nutcracker for Kids',
#  b'World Classical 2010', b'Russian Composers',
#  b'Hallelujah Classical Collection', b'Thanksgiving Classical Moods',
#  b"Classical Piano's Greatest Moments",
#  b'Kids Orchestral Music for Play & Relaxation',
#  b'Mama Mia - The Italian Classical Wedding', b'Mozart For Brain Power',
#  b'Requiem, Finished by Franz Xaver Suessmayr (Vollendet von Franz Xaver Suessmayr)',
#  b'Thanksgiving Classical Moods',
#  b'Rimsky-Korsakov, Glinka, Smetana, Janacek & Bayer: Symphonic Pieces',
#  b'Mozart For Brain Power', b'World Classical 2010',
#  b'Liszt: Solo Piano Works', b'World Classical 2010',
#  b'Pontinen, Roland: Music for A Rainy Day',
#  b'Rachmaninov: Complete Preludes', b'Soundtrack For Thanksgiving',
#  b'World Classical 2010',
#  b'Classical Relaxation Collection - The Greatest Tunes On Earth',
#  b'World Classical 2010', b'Traveling Classics - 4 Babies',
#  b'Thanksgiving Classical Moods', b'100 World Classical Masterpieces',
#  b'World Classical 2010', b'Wagner, R.: Orchestral Music From Operas',
#  b'Peer Gynt Suite N1 Y N2', b'100 World Classical Masterpieces']]]>, 'artist_genres_pl': <tf.RaggedTensor [[[b"'alternative rock', 'anti-folk', 'indie rock', 'modern rock', 'permanent wave', 'rock'",
#  b"'candy pop', 'dance pop', 'edm', 'electropop', 'metropopolis', 'pop', 'pop dance', 'swedish electropop', 'swedish synthpop'",
#  b"'alternative dance', 'downtempo', 'electronica', 'trip hop'",
#  b"'gauze pop', 'indietronica', 'shiver pop'"]],
#  [[b"'british orchestra', 'orchestra'",
#  b"'classical', 'post-romantic era', 'russian romanticism', 'ukrainian classical'",
#  b'NONE', b'NONE',
#  b"'classical', 'late romantic era', 'russian romanticism'",
#  b"'classical', 'impressionism', 'neoclassicism', 'post-romantic era'",
#  b"'classical', 'classical era', 'early romantic era'",
#  b"'classical tenor', 'italian tenor', 'operatic pop'",
#  b"'american modern classical', 'classical', 'early modern classical', 'tin pan alley'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b"'american modern classical', 'classical', 'early modern classical'",
#  b'NONE', b"'british orchestra'", b'NONE', b"'british orchestra'", b'NONE',
#  b'NONE', b"'british orchestra'", b'NONE', b"'british orchestra'",
#  b"'radio symphony'", b"'caucasian classical'", b'NONE',
#  b"'classical', 'early romantic era', 'polish classical'",
#  b"'british orchestra', 'orchestra'", b'NONE',
#  b"'classical', 'french opera', 'french romanticism', 'late romantic era'",
#  b"'classical', 'early modern classical', 'neoclassicism', 'russian modern classical'",
#  b'NONE', b"'hungarian classical performance', 'orchestra'", b'NONE',
#  b"'british orchestra'", b"'radio symphony'",
#  b"'british orchestra', 'orchestra'", b"'classical', 'classical era'",
#  b"'classical', 'classical era'",
#  b"'classical', 'classical performance', 'orchestra', 'symfonicky orchestr'",
#  b'NONE', b'NONE', b"'british orchestra'",
#  b"'classical', 'classical era', 'early romantic era', 'german romanticism'",
#  b"'classical', 'late romantic era'", b"'radio symphony'",
#  b"'classical', 'late romantic era', 'russian romanticism'",
#  b"'balkan classical piano'", b'NONE', b"'british orchestra', 'orchestra'",
#  b"'classical', 'german romanticism', 'late romantic era'",
#  b"'classical', 'classical era', 'early romantic era', 'german romanticism'",
#  b'NONE', b"'british orchestra'", b"'radio symphony'", b'NONE', b'NONE',
#  b'NONE', b"'german classical piano'", b'NONE', b"'radio symphony'",
#  b'NONE', b"'classical', 'czech classical', 'late romantic era'",
#  b"'classical', 'early romantic era', 'polish classical'",
#  b"'classical', 'classical performance', 'orchestra', 'symfonicky orchestr'",
#  b'NONE', b'NONE', b"'british orchestra', 'orchestra'", b'NONE', b'NONE',
#  b'NONE', b"'british orchestra', 'orchestra'",
#  b"'classical', 'early modern classical', 'neoclassicism', 'russian modern classical'",
#  b"'british orchestra'", b'NONE', b"'british orchestra'",
#  b"'avant-garde', 'classical', 'late romantic era', 'russian romanticism'",
#  b"'british orchestra'", b"'classical', 'classical era'", b'NONE', b'NONE',
#  b'NONE', b"'classical', 'classical era'", b'NONE',
#  b"'classical', 'late romantic era'", b'NONE',
#  b"'classical', 'early modern classical', 'impressionism', 'neoclassicism', 'post-romantic era'",
#  b"'classical', 'post-romantic era', 'russian romanticism', 'ukrainian classical'",
#  b'NONE', b"'hungarian classical performance', 'orchestra'",
#  b"'avant-garde', 'classical', 'late romantic era', 'russian romanticism'",
#  b'NONE', b'NONE', b'NONE', b"'british orchestra', 'orchestra'", b'NONE',
#  b"'classical', 'german opera', 'german romanticism', 'late romantic era'",
#  b'NONE', b"'balkan classical piano'"]]]>, 'artist_name_pl': <tf.RaggedTensor [[[b'Beck', b'Icona Pop', b'Brazilian Girls', b'Glass Animals']],
#  [[b'London Philharmonic Orchestra', b'Sergei Rachmaninoff',
#  b'Pairs France Royal Philharmonic Orchestra',
#  b'Symphonic Festival Orchestra', b'Pyotr Ilyich Tchaikovsky',
#  b'Maurice Ravel', b'Franz Schubert', b'Andrea Bocelli',
#  b'George Gershwin', b'Aaron Copland', b'Aaron Copland', b'Aaron Copland',
#  b'Aaron Copland', b'Aaron Copland', b'Aaron Copland', b'Aaron Copland',
#  b'Aaron Copland', b'Aaron Copland', b'Aaron Copland', b'Aaron Copland',
#  b'Aaron Copland', b'Aaron Copland', b'Aaron Copland', b'Aaron Copland',
#  b'Helge Sunde', b'London Festival Orchestra',
#  b"St. Martin's Symphony Of Los Angeles", b'London Festival Orchestra',
#  b'Berlin Symphonic Orchestra', b'Philharmonia Slavonica',
#  b'London Festival Orchestra',
#  b'Philharmonische Vereinigung Arte Sinfonica',
#  b'London Festival Orchestra', b'Radio Orchestra Berlin',
#  b'Karen Khachaturian', b'Maurizio Mastrini',
#  b'Fr\xc3\xa9d\xc3\xa9ric Chopin', b'Royal Philharmonic Orchestra',
#  b'Orchestra of the Vienna Concert House', b'Georges Bizet',
#  b'Sergei Prokofiev', b'Orchestra of the Vienna Concert House',
#  b'Budapest Philharmonic Orchestra', b'Nordic Symphony Orchestra',
#  b'London Festival Orchestra', b'Radio Orchestra Berlin',
#  b'Royal Philharmonic Orchestra', b'Franz Joseph Haydn',
#  b'Wolfgang Amadeus Mozart', b'Czech Philharmonic Orchestra',
#  b'South German Philharmonic Orchestra',
#  b'South German Philharmonic Orchestra', b'London Festival Orchestra',
#  b'Ludwig van Beethoven', b'Franz Liszt', b'Radio Orchestra Berlin',
#  b'Pyotr Ilyich Tchaikovsky', b'Dubravka Tom\xc5\xa1i\xc4\x8d',
#  b'Philharmonia Slavonica', b'London Philharmonic Orchestra',
#  b'Johannes Brahms', b'Ludwig van Beethoven',
#  b'The Classical Renaissance Symphony', b'London Festival Orchestra',
#  b'Radio Orchestra Berlin', b"Orchestra da Camera Dell'Arte",
#  b'The Classical Renaissance Symphony',
#  b'The Classical Renaissance Symphony', b'Peter Schmalfuss',
#  b'Boston Chamber Music Players', b'Radio Orchestra Berlin',
#  b'Michael Bernstein', b'Bed\xc5\x99ich Smetana',
#  b'Fr\xc3\xa9d\xc3\xa9ric Chopin', b'Czech Philharmonic Orchestra',
#  b'Orchestra of the Vienna Concert House', b'South German Philharmonic',
#  b'Royal Philharmonic Orchestra', b'Philharmonia Slavonica', b'B Berkyova',
#  b'Snowflake Symphonie', b'Royal Philharmonic Orchestra',
#  b'Sergei Prokofiev', b'London Festival Orchestra', b'Georg Fischer',
#  b'London Festival Orchestra', b'Nikolai Rimsky-Korsakov',
#  b'London Festival Orchestra', b'Wolfgang Amadeus Mozart',
#  b'Orchestra of the Vienna Concert House', b'Chamber Orchestra of Brabant',
#  b'Philharmonica Slavonica', b'Wolfgang Amadeus Mozart',
#  b'Berlin Symphonic Orchestra', b'Franz Liszt', b'Philharmonia Slavonica',
#  b'Manuel de Falla', b'Sergei Rachmaninoff',
#  b'All-Union Radio Symphony Orchestra', b'Budapest Philharmonic Orchestra',
#  b'Nikolai Rimsky-Korsakov', b'South German Philharmonic Orchestra',
#  b'The Royal Festival Orchest...', b'Nordic Symphony Orchestra',
#  b'Royal Philharmonic Orchestra', b'Philharmonia Slavonica',
#  b'Richard Wagner', b'Orquesta Sinf\xc3\xb3nica De Radio Hamburgo',
#  b'Dubravka Tom\xc5\xa1i\xc4\x8d']]]>, 'artist_pop_pl': <tf.RaggedTensor [[[69.0, 71.0, 42.0, 87.0]],
#  [[68.0, 67.0, 0.0, 18.0, 72.0, 64.0, 68.0, 71.0, 55.0, 51.0, 51.0, 51.0,
#  51.0, 51.0, 51.0, 51.0, 51.0, 51.0, 51.0, 51.0, 51.0, 51.0, 51.0, 51.0,
#  2.0, 53.0, 25.0, 53.0, 25.0, 32.0, 53.0, 28.0, 53.0, 36.0, 13.0, 22.0,
#  78.0, 71.0, 9.0, 61.0, 60.0, 9.0, 34.0, 0.0, 53.0, 36.0, 71.0, 60.0, 79.0,
#  50.0, 31.0, 31.0, 53.0, 76.0, 66.0, 36.0, 72.0, 31.0, 32.0, 68.0, 68.0,
#  76.0, 10.0, 53.0, 36.0, 10.0, 10.0, 10.0, 46.0, 0.0, 36.0, 20.0, 50.0,
#  78.0, 50.0, 9.0, 11.0, 71.0, 32.0, 1.0, 26.0, 71.0, 60.0, 53.0, 4.0, 53.0,
#  53.0, 53.0, 79.0, 9.0, 0.0, 4.0, 79.0, 25.0, 66.0, 32.0, 47.0, 67.0, 0.0,
#  34.0, 53.0, 31.0, 0.0, 0.0, 71.0, 32.0, 58.0, 36.0, 31.0]]]>, 'artists_followers_pl': <tf.RaggedTensor [[[1322123.0, 676739.0, 50634.0, 2604423.0]],
#  [[244229.0, 552792.0, 107.0, 170.0, 1124260.0, 412386.0, 922403.0,
#  2075599.0, 254031.0, 80971.0, 80971.0, 80971.0, 80971.0, 80971.0, 80971.0,
#  80971.0, 80971.0, 80971.0, 80971.0, 80971.0, 80971.0, 80971.0, 80971.0,
#  80971.0, 96.0, 8101.0, 1088.0, 8101.0, 1694.0, 3013.0, 8101.0, 184.0,
#  8101.0, 2867.0, 106.0, 335.0, 2706872.0, 114986.0, 60.0, 206798.0,
#  216873.0, 60.0, 3412.0, 30.0, 8101.0, 2867.0, 114986.0, 523542.0,
#  4500792.0, 16598.0, 1507.0, 1507.0, 8101.0, 4350364.0, 650028.0, 2867.0,
#  1124260.0, 3468.0, 3013.0, 244229.0, 789112.0, 4350364.0, 319.0, 8101.0,
#  2867.0, 37.0, 319.0, 319.0, 8690.0, 4.0, 2867.0, 126.0, 75519.0,
#  2706872.0, 16598.0, 60.0, 302.0, 114986.0, 3013.0, 6.0, 103.0, 114986.0,
#  216873.0, 8101.0, 7.0, 8101.0, 95551.0, 8101.0, 4500792.0, 60.0, 1.0,
#  79.0, 4500792.0, 1694.0, 650028.0, 3013.0, 38656.0, 552792.0, 4.0, 3412.0,
#  95551.0, 1507.0, 51.0, 30.0, 114986.0, 3013.0, 544220.0, 7220.0, 3468.0]]]>, 'duration_ms_songs_pl': <tf.RaggedTensor [[[222335.0, 157152.0, 248053.0, 289306.0]],
#  [[502613.0, 670360.0, 288333.0, 194266.0, 348973.0, 1052893.0, 276866.0,
#  253533.0, 987266.0, 195626.0, 168560.0, 183000.0, 217000.0, 210306.0,
#  244866.0, 66960.0, 192133.0, 205533.0, 468666.0, 231400.0, 283760.0,
#  212800.0, 116440.0, 135266.0, 126293.0, 582066.0, 349706.0, 116066.0,
#  242040.0, 392106.0, 243400.0, 62626.0, 148906.0, 206800.0, 153866.0,
#  260653.0, 204800.0, 143866.0, 262733.0, 131893.0, 220200.0, 147986.0,
#  191373.0, 206906.0, 395533.0, 249866.0, 89000.0, 388240.0, 394573.0,
#  278973.0, 259693.0, 114200.0, 295160.0, 436773.0, 716293.0, 170466.0,
#  165573.0, 125226.0, 142066.0, 318000.0, 91000.0, 204000.0, 236893.0,
#  36466.0, 310000.0, 85040.0, 144826.0, 140666.0, 173000.0, 92293.0,
#  198066.0, 242360.0, 377760.0, 392106.0, 501373.0, 309826.0, 124066.0,
#  74466.0, 261426.0, 335960.0, 120000.0, 187466.0, 92120.0, 259693.0,
#  202360.0, 499733.0, 77493.0, 203933.0, 94800.0, 285533.0, 320706.0,
#  129906.0, 422333.0, 232026.0, 705320.0, 281733.0, 217000.0, 237986.0,
#  333000.0, 194626.0, 103733.0, 50733.0, 205299.0, 237960.0, 261666.0,
#  43600.0, 325000.0, 155786.0, 148533.0]]]>, 'track_name_pl': <tf.RaggedTensor [[[b'Wow',
#  b'I Love It (feat. Charli XCX) - feat. Charli XCX [Original Version]',
#  b'Pussy', b'Gooey']],
#  [[b'Adagio for Strings, Op. 11a',
#  b'Piano Concerto No. 2 in C Minor, Op. 18: I. Moderato',
#  b'Symphonie Fantastique - March To The Scaffold',
#  b'Swan Lake, Ballet suite, op. 20a: I. Scene " Lake in the Moonlight "',
#  b'Swan Lake Suite, Op. 20a: Act I: Valse', b'Bol\xc3\xa9ro, M. 81',
#  b'Winterreise, Op.89, D.911: Der Lindenbaum',
#  b'Por Ti Volare (Con Te Partiro) - Spanish Version', b'Rhapsody In Blue',
#  b'Fanfare for the Common Man', b'Appalachian Spring: Very Slowly',
#  b'Appalachian Spring: Allegro', b'Appalachian Spring: Moderato',
#  b'Appalachian Spring: Fast', b'Appalachian Spring: Subito allegro',
#  b'Appalachian Spring: As At First (Slowly)',
#  b'Appalachian Spring: Doppio movimento',
#  b'Appalachian Spring: Moderato - Coda',
#  b'Rodeo: Four Dance Episodes: I. Buckaroo Holiday',
#  b'Rodeo: Four Dance Episodes: II. Corral Nocturne',
#  b'Rodeo: Four Dance Episodes: III. Saturday Night Waltz',
#  b'Rodeo: Four Dance Episodes: IV. Hoedown',
#  b'Fanfare for the Common Man (Version of Symphony No. 3, Fourth Movement) - Excerpt',
#  b"Billy the Kid: Celebration (after Billy's capture) - Orchestral Suite Excerpts",
#  b'Waldszenen (Forest Scenes), for piano, Op. 82 - No.7, Vogel Als Prophet',
#  b'Mozart: Concerto for Two Pianos & Orchestra in E flat, K. 365',
#  b'Symphony No.3 in F Major Op.90 - 3rd Movement',
#  b'Chopin: Waltz In D Flat, Op. 64/1, "Minuet"',
#  b'Serenade For Strings In C Major Op.48 (Excerpt)',
#  b'Brandenburg Concerto No.3 In G Major, 1st Movement',
#  b'Chopin: Nocturne #20 In C Sharp Minor, Bi 49',
#  b'Prelude Nr. 3, G-Dur, op. 28', b'Chopin: Mazurka #15 In C, Op. 24/2',
#  b'Waltz from Maskarade', b'Sabre Dance', b"Sogno D'Amore",
#  b'Nocturne, Op. 15: No. 2', b'The Love for Three Oranges , No.3, Marche',
#  b'4.Offertorium: Hostias: Requiem in D Minor, K 626',
#  b'Carmen, Opera Suite No. 2: II. Habanera (Act 1)',
#  b'The Love for Three Oranges: No. 4, Scherzo',
#  b'3.Sequentia: Rex trmendae: Requiem in D Minor, K 626', b'Humoreske',
#  b"Peer Gynt Suite for orchestra (or piano or piano, 4 hands) No. 2, Op. 55 - Solveig's Song",
#  b'Chopin: Polonaise In A Flat, Op. 53, "Heroic"',
#  b'The Marriage of Figaro (overture)', b'Waltz in A Flat Major Op.39/15',
#  b'Symphony No. 94 in G major Hob 1/94 "Surprise": II. Andante',
#  b'Don Giovanni, K. 527: Overture', b"Carillon' from L'Arl\xc3\xa9sienne",
#  b'Vocalise Op.34/14', b'Moment Musical In F Minor',
#  b'Chopin: Fantasie Impromptu #4 In C Sharp Minor, Op. 66',
#  b'Symphony No. 5 in C Minor, Op. 67: I. Allegro con brio',
#  b'Symphonic Poem No. 4 "Orpheus"', b'Holberg Suite Op.40 - Prelude',
#  b'Tchaikovsky: The Nutcracker "Scenes Des Ballet": March - Produced',
#  b'Prelude No 4 In E Minor, Op 28', b'Toccata and Fugue in D Minor',
#  b'Florentiner Marsch op. 214',
#  b'Hungarian Dance No. 18 in D Major: Molto vivace',
#  b'Bagatelle in A Minor, WoO 59, "Fur Elise"',
#  b'Bach: Minuet in G Major (The Lovers Concerto)',
#  b'Bizet: Flower Song From Carmen', b'Rhapsody In Blue',
#  b'Wassermusik Suite Nr. 2, D-Dur, HWV 349: III. Minuet',
#  b'Delius: Aquarelle (Unidentified)',
#  b"Schubert: 'Unfinished Symphony' No. 8 in B Minor",
#  b'Walzer, Nr. 14, E-Moll, op. posth.',
#  b'Orchestral Suite No. 2 in B minor, BWV 1067 - Badinerie',
#  b'Intermezzo from Cavalleria Rusticana',
#  b'Claire De Lune (From Twilight)', b'Overture of The Bartered Bride',
#  b'Barcarolle in F Sharp, Op. 60',
#  b'Concerto for Piano and Orchestra No. 2 in A major: Quasi Adagio- Allegretto Vivace- Allegro Animato',
#  b'1. Introitus: Requiem: Requiem in D Minor, K 626', b'Water Music - Air',
#  b'Hungarian Dance No.5 In G Minor', b"Sleeper's Wake",
#  b'Don Giovanni: Madamina', b'Ave Maria', b'Lohengrin Prelude to Act III',
#  b'The Love for Three Oranges: No. 2, Scene Infernale',
#  b'Chopin: Etude #12 In C Minor, Op. 10/12, "Revolutionary"',
#  b'Piano Sonata No. 8 in C minor ("Path\xc3\xa9tique"), Op. 13 - Excerpt',
#  b'Mozart: Piano Concerto No. 26 in D, K. 537, "Coronation"',
#  b'Flight of the Bumble Bee', b'Strauss: Vienna Blood',
#  b'Don Giovanni, K. 527, Act I: "Ah fuggi il traditor"',
#  b'6.Benedictus: Requiem in D Minor, K 626',
#  b'Orchestral Suite No. 3 in D major, BWV 1068 - Air on a G string',
#  b'Sinfoniettas for Orchestra No. 1',
#  b'Don Giovanni, K. 527, Act I: "Don Ottavio, son morta"',
#  b'1812 Overture Op.49 - Finale',
#  b'Trauerode (Les Morts: Oriason), S. 268,2', b'Sheep May Safely Graze',
#  b'El amor brujo: Danse rituelle de feu (Ritual Fire Dance)',
#  b'10 Preludes, Op. 23: No. 5 in G Minor: Alla marcia',
#  b'Symphony No. 6 in B minor ("Path\xc3\xa9tique"), Op. 74 - Scherzo',
#  b'Nocturne In B Major Op.40',
#  b'Scheherazade Op.35 - The Young Prince and Princess',
#  b'Album For The Young Op.68/10 - The Merry Peasant',
#  b'Rossini: William Tell Overture',
#  b'Peer Gynt Suite for orchestra (or piano or piano, 4 hands) No. 1, Op. 46 - Morning',
#  b'The Bartered Bride, Overture', b'Little Prelude In C Major',
#  b'Die Walkure, Act III: Ride of the Valkyries',
#  b'Suite N1. En LA Gruta Del Rey De La Monta\xc3\xb1a',
#  b'The Girl with the Flaxen Hair']]]>, 'track_pop_pl': <tf.RaggedTensor [[[55.0, 73.0, 44.0, 40.0]],
#  [[46.0, 4.0, 17.0, 30.0, 12.0, 0.0, 26.0, 0.0, 53.0, 42.0, 16.0, 23.0, 13.0,
#  14.0, 13.0, 12.0, 24.0, 22.0, 11.0, 9.0, 10.0, 30.0, 9.0, 8.0, 0.0, 22.0,
#  9.0, 49.0, 7.0, 40.0, 40.0, 29.0, 29.0, 32.0, 24.0, 35.0, 32.0, 8.0, 9.0,
#  44.0, 0.0, 7.0, 29.0, 0.0, 17.0, 33.0, 35.0, 4.0, 5.0, 4.0, 32.0, 29.0,
#  34.0, 19.0, 2.0, 19.0, 26.0, 8.0, 28.0, 3.0, 8.0, 36.0, 9.0, 1.0, 20.0,
#  1.0, 6.0, 7.0, 42.0, 0.0, 30.0, 37.0, 0.0, 8.0, 14.0, 20.0, 22.0, 40.0,
#  18.0, 6.0, 20.0, 19.0, 0.0, 6.0, 0.0, 20.0, 10.0, 0.0, 5.0, 7.0, 0.0, 0.0,
#  4.0, 29.0, 6.0, 28.0, 16.0, 49.0, 0.0, 28.0, 0.0, 28.0, 43.0, 0.0, 12.0,
#  27.0, 55.0, 36.0, 30.0]]]>})

# %%
# for raw_record in raw_train_ds.take(1):
#     example = tf.train.Example()
#     example.ParseFromString(raw_record.numpy())
#     print(raw_record)

# %% [markdown]
# ## Candidate features

# %% [markdown]
# ### parsing function - candidate data

# %%
# feature_dict = tf.io.parse_single_example(example_batch[0], features)

SAMPLE_FILE = "gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000002-8473.tfrec"
sample_dataset = tf.data.TFRecordDataset(SAMPLE_FILE)

for raw_record in sample_dataset.take(1):
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())
    print(example)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1970/366318912.py in <module>
#       2
#       3 SAMPLE_FILE = "gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000002-8473.tfrec"
# ----> 4 sample_dataset = tf.data.TFRecordDataset(SAMPLE_FILE)
#       5
#       6 for raw_record in sample_dataset.take(1):
#
# NameError: name 'tf' is not defined

# %%
# =====================
# Candidate TF Records
# =====================

# candidate_features = {
#     'track_name': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
#     'artist_name': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
#     'album_name': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
#     'track_uri': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
#     # 'artist_uri': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
#     # 'album_uri': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
#     'duration_ms': tf.io.FixedLenFeature(dtype=tf.int64, shape=(1)),
#     'track_pop': tf.io.FixedLenFeature(dtype=tf.int64, shape=(1)),
#     'artist_pop': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
#     'artist_genres': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
#     'artist_followers': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
# }

candidate_features = {
    #candidate features
    'track_name_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'artist_name_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'album_name_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'track_uri_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'duration_ms_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'track_pop_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'artist_pop_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
    'artist_genres_can': tf.io.FixedLenFeature(dtype=tf.string, shape=(1)),
    'artist_followers_can': tf.io.FixedLenFeature(dtype=tf.float32, shape=(1)),
}

def parse_candidate_tfrecord_fn(example):
    example = tf.io.parse_single_example(
        example, 
        features=candidate_features, 
    )
    return example

# TF data input pipeline params
options = tf.data.Options()
options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.DATA

# parse candidate data
raw_candidate_ds = tf.data.TFRecordDataset(candidate_files)

parsed_candidate_ds = raw_candidate_ds.map(
    parse_candidate_tfrecord_fn, 
    num_parallel_calls=tf.data.AUTOTUNE
).with_options(options)

# %%
candidate_files
# Out:
# ['gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000000-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000001-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000002-8473.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000003-3753.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000004-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000005-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000006-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000007-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000008-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000009-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000010-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000011-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000012-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000013-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000014-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000015-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000016-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000017-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000018-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000019-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000020-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000021-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000022-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000023-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000024-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000025-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000026-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000027-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000028-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000029-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000030-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000031-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000032-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000033-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000034-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000035-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000036-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000037-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000038-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000039-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000040-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000041-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000042-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000043-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000044-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000045-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000046-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000047-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000048-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000049-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000050-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000051-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000052-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000053-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000054-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000055-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000056-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000057-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000058-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000059-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000060-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000061-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000062-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000063-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000064-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000065-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000066-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000067-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000068-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000069-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000070-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000071-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000072-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000073-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000074-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000075-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000076-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000077-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000078-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000079-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000080-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000081-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000082-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000083-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000084-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000085-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000086-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000087-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000088-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000089-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000090-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000091-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000092-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000093-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000094-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000095-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000096-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000097-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000098-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000099-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000100-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000101-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000102-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000103-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000104-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000105-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000106-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000107-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000108-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000109-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000110-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000111-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000112-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000113-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000114-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000115-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000116-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000117-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000118-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000119-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000120-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000121-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000122-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000123-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000124-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000125-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000126-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000127-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000128-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000129-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000130-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000131-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000132-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000133-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000134-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000135-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000136-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000137-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000138-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000139-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000140-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000141-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000142-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000143-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000144-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000145-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000146-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000147-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000148-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000149-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000150-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000151-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000152-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000153-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000154-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000155-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000156-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000157-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000158-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000159-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000160-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000161-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000162-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000163-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000164-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000165-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000166-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000167-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000168-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000169-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000170-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000171-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000172-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000173-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000174-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000175-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000176-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000177-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000178-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000179-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000180-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000181-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000182-12227.tfrec',
#  'gs://spotify-tfrecords-blog/candidate_tracks_v2/spotify_000183-12227.tfrec']

# %%
cnt = parsed_candidate_ds.reduce(np.int64(0), lambda x, _: x + 1)
cnt
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=2237540>

# %%
for raw_record in parsed_candidate_ds.take(1):
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())
    print(raw_record)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_22801/444426749.py in <module>
#       1 for raw_record in parsed_candidate_ds.take(1):
#       2     example = tf.train.Example()
# ----> 3     example.ParseFromString(raw_record.numpy())
#       4     print(raw_record)
#
# AttributeError: 'dict' object has no attribute 'numpy'

# %%
for _ in parsed_candidate_ds.batch(3).take(1):
    print(_)
# Out:
# 2022-07-12 05:11:32.133008: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133082: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133127: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133165: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133207: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133272: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133316: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133384: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133467: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133552: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133606: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133680: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133748: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133820: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133886: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.133964: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# 2022-07-12 05:11:32.134030: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at example_parsing_ops.cc:94 : INVALID_ARGUMENT: Feature: album_name (data type: string) is required but could not be found.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tmp/ipykernel_22801/2356479152.py in <module>
# ----> 1 for _ in parsed_candidate_ds.batch(3).take(1):
#       2     print(_)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in __next__(self)
#     764   def __next__(self):
#     765     try:
# --> 766       return self._next_internal()
#     767     except errors.OutOfRangeError:
#     768       raise StopIteration
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in _next_internal(self)
#     750           self._iterator_resource,
#     751           output_types=self._flat_output_types,
# --> 752           output_shapes=self._flat_output_shapes)
#     753
#     754       try:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py in iterator_get_next(iterator, output_types, output_shapes, name)
#    3015       return _result
#    3016     except _core._NotOkStatusException as e:
# -> 3017       _ops.raise_from_not_ok_status(e, name)
#    3018     except _core._FallbackException:
#    3019       pass
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7162 def raise_from_not_ok_status(e, name):
#    7163   e.message += (" name: " + name if name is not None else "")
# -> 7164   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7165
#    7166
#
# InvalidArgumentError: Feature: album_name (data type: string) is required but could not be found.
# 	 [[{{node ParseSingleExample/ParseExample/ParseExampleV2}}]] [Op:IteratorGetNext]

# %% [markdown]
# ## Import Vocab & Stats

# %%
import pickle as pkl
from google.cloud import storage

BUCKET_NAME = 'spotify-v1'
FILE_PATH = 'vocabs/v1_string_vocabs'
FILE_NAME = 'string_vocabs_v1_20220705-202905.txt'
DESTINATION_FILE = 'downloaded_vocabs.txt'

client = storage.Client()

with open(f'{DESTINATION_FILE}', 'wb') as file_obj:
    client.download_blob_to_file(
        f'gs://{BUCKET_NAME}/{FILE_PATH}/{FILE_NAME}', file_obj)

    
with open(f'{DESTINATION_FILE}', 'rb') as pickle_file:
    vocab_dict_load = pkl.load(pickle_file)

# %%
# vocab_dict_load['unique_pids']
# vocab_dict_load

# %% [markdown]
# ### TODO: Add stats to vocab_file

# %%
avg_duration_ms_seed_pl = 13000151.68
var_duration_ms_seed_pl = 133092900971233.58
vocab_dict_load['avg_duration_ms_seed_pl']=avg_duration_ms_seed_pl
vocab_dict_load['var_duration_ms_seed_pl']=var_duration_ms_seed_pl

avg_n_songs_pl = 55.21
var_n_songs_pl = 2317.54
vocab_dict_load['avg_n_songs_pl']=avg_n_songs_pl
vocab_dict_load['var_n_songs_pl']=var_n_songs_pl

avg_n_artists_pl = 30.56
var_n_artists_pl = 769.26
vocab_dict_load['avg_n_artists_pl']=avg_n_artists_pl
vocab_dict_load['var_n_artists_pl']=var_n_artists_pl

avg_n_albums_pl = 40.25
var_n_albums_pl = 1305.54
vocab_dict_load['avg_n_albums_pl']=avg_n_albums_pl
vocab_dict_load['var_n_albums_pl']=var_n_albums_pl

avg_artist_pop = 16.08
var_artist_pop = 300.64
vocab_dict_load['avg_artist_pop']=avg_artist_pop
vocab_dict_load['var_artist_pop']=var_artist_pop

avg_duration_ms_songs_pl = 234823.14
var_duration_ms_songs_pl = 5558806228.41
vocab_dict_load['avg_duration_ms_songs_pl']=avg_duration_ms_songs_pl
vocab_dict_load['var_duration_ms_songs_pl']=var_duration_ms_songs_pl

avg_artist_followers = 43337.77
var_artist_followers = 377777790193.57
vocab_dict_load['avg_artist_followers']=avg_artist_followers
vocab_dict_load['var_artist_followers']=var_artist_followers

avg_track_pop = 10.85
var_track_pop = 202.18
vocab_dict_load['avg_track_pop']=avg_track_pop
vocab_dict_load['var_track_pop']=var_track_pop

# %% [markdown]
# # Two-Tower

# %%
parsed_train_ds
# Out:
# <_OptionsDataset element_spec=({'album_name_can': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'album_name_seed_track': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'album_uri_can': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'album_uri_seed_track': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'artist_followers_can': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'artist_followers_seed_track': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'artist_genres_can': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'artist_genres_seed_track': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'artist_name_can': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'artist_name_seed_track': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'artist_pop_can': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'artist_pop_seed_track': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'artist_uri_can': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'artist_uri_seed_track': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'collaborative': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'description_pl': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'duration_ms_can': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'duration_ms_seed_pl': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'duration_seed_track': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'n_songs_pl': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'name': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'num_albums_pl': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'num_artists_pl': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'pos_seed_track': TensorSpec(shape=(1,), dtype=tf.int64, name=None), 'track_name_can': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'track_name_seed_track': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'track_pop_can': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'track_pop_seed_track': TensorSpec(shape=(1,), dtype=tf.float32, name=None), 'track_uri_can': TensorSpec(shape=(1,), dtype=tf.string, name=None), 'track_uri_seed_track': TensorSpec(shape=(1,), dtype=tf.string, name=None)}, {'album_name_pl': RaggedTensorSpec(TensorShape([None, None]), tf.string, 1, tf.int32), 'artist_genres_pl': RaggedTensorSpec(TensorShape([None, None]), tf.string, 1, tf.int32), 'artist_name_pl': RaggedTensorSpec(TensorShape([None, None]), tf.string, 1, tf.int32), 'artist_pop_pl': RaggedTensorSpec(TensorShape([None, None]), tf.float32, 1, tf.int32), 'artists_followers_pl': RaggedTensorSpec(TensorShape([None, None]), tf.float32, 1, tf.int32), 'duration_ms_songs_pl': RaggedTensorSpec(TensorShape([None, None]), tf.float32, 1, tf.int32), 'track_name_pl': RaggedTensorSpec(TensorShape([None, None]), tf.string, 1, tf.int32), 'track_pop_pl': RaggedTensorSpec(TensorShape([None, None]), tf.float32, 1, tf.int32), 'track_uri_pl': RaggedTensorSpec(TensorShape([None, None]), tf.string, 1, tf.int32)})>

# %%
# Test # TODO: remove

for x in parsed_train_ds.take(5).as_numpy_iterator():
    pprint(x['track_pop_pl'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_22801/3422332708.py in <module>
#       1 # Test # TODO: remove
#       2
# ----> 3 for x in parsed_train_ds.take(5).as_numpy_iterator():
#       4     pprint(x['track_pop_pl'])
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __next__(self)
#    4476       return numpy
#    4477
# -> 4478     return nest.map_structure(to_numpy, next(self._iterator))
#    4479
#    4480   def next(self):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/util/nest.py in map_structure(func, *structure, **check_types_dict)
#     226
#     227   return pack_sequence_as(
# --> 228       structure[0], [func(*x) for x in entries])
#     229
#     230
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/util/nest.py in <listcomp>(.0)
#     226
#     227   return pack_sequence_as(
# --> 228       structure[0], [func(*x) for x in entries])
#     229
#     230
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in to_numpy(x)
#    4469
#    4470     def to_numpy(x):
# -> 4471       numpy = x._numpy()  # pylint: disable=protected-access
#    4472       if isinstance(numpy, np.ndarray):
#    4473         # `numpy` shares the same underlying buffer as the `x` Tensor.
#
# AttributeError: 'RaggedTensor' object has no attribute '_numpy'

# %%
test_instance = {
    'name': np.asarray([b'Best Christmas']),
    'collaborative': np.asarray([b'false']),
    # 'pid': np.asarray([173671]),
    'description_pl': np.asarray([b'test description']),
    'duration_ms_seed_pl': np.asarray([5458995.]),
    'n_songs_pl': np.asarray([58.]),
    'num_artists_pl': np.asarray([19.]),
    'num_albums_pl': np.asarray([27.]),
    'artist_name_pl': np.asarray([[b'Juan Luis Guerra 4.40', b'Prince Royce', b'Luis Vargas']]),
    'track_uri_pl': np.asarray([[b'spotify:track:1g0IBPZTRP7VYkctJ4Qafg',b'spotify:track:43wUzbYxEFoXugYkgTzMWp']]),
    'track_name_pl': np.asarray([[b'Lover Come Back', b'White Lightning', b'Shake Me Down']]),
    'duration_ms_songs_pl': np.asarray([[245888., 195709., 283906., 271475., 300373., 275173., 236145.,]]),
    'album_name_pl': np.asarray([[b'Silsulim', b'Sara Shara', b'Muzika Vesheket', b'Ba La Lirkod']]),
    'artist_pop_pl': np.asarray([[81., 81., 70., 66., 66., 66., 46., 87.]]),
    'artists_followers_pl': np.asarray([[3.556710e+05, 8.200000e+02, 1.510000e+02, 1.098080e+05,]]),
    'artist_genres_pl': np.asarray([[b"'israeli pop', 'jewish pop'", b"'israeli pop', 'jewish pop'",]]),
    'track_pop_pl': np.asarray([[70, 77, 50, 44, 30, 28, 15, 26, 15, 18, 46, 38,]])
}

# %% [markdown]
# ## Query Tower

# %%
EMBEDDING_DIM = 32
PROJECTION_DIM = 5
SEED = 1234
USE_CROSS_LAYER=True
DROPOUT='False'
DROPOUT_RATE='0.33'

class QueryModel(tf.keras.Model):
    def __init__(self, layer_sizes, vocab_dict):
        super().__init__()

        # ========================================
        # non-sequence playlist features
        # ========================================
        
        # Feature: playlist name
        self.pl_name_text_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.TextVectorization(
                    # max_tokens=len(vocab_dict["name"]), # not needed if passing vocab
                    vocabulary=vocab_dict['name'], 
                    name="pl_name_txt_vectorizer", 
                    ngrams=2
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict["name"]),
                    output_dim=EMBEDDING_DIM,
                    mask_zero=False,
                    name="pl_name_emb_layer",
                ),
                tf.keras.layers.GlobalAveragePooling1D(name="pl_name_pooling"),
            ], name="pl_name_emb_model"
        )
        
        # Feature: collaborative
        collaborative_vocab = np.array([b'false', b'true'])
        
        self.pl_collaborative_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.StringLookup(
                    vocabulary=collaborative_vocab, 
                    mask_token=None, 
                    name="pl_collaborative_lookup", 
                    output_mode='int'
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(collaborative_vocab),
                    output_dim=EMBEDDING_DIM,
                    mask_zero=False,
                    name="pl_collaborative_emb_layer",
                ),
            ], name="pl_collaborative_emb_model"
        )
        
        # # Feature: pid
        # self.pl_pid_embedding = tf.keras.Sequential(
        #     [
        #         tf.keras.layers.IntegerLookup(
        #             vocabulary=vocab_dict['unique_pids'], 
        #             mask_token=None, 
        #             name="pl_pid_lookup", 
        #             # output_mode='int'
        #         ),
        #         tf.keras.layers.Embedding(
        #             input_dim=len(vocab_dict['unique_pids']),
        #             output_dim=EMBEDDING_DIM,
        #             mask_zero=False,
        #             name="pl_pid_emb_layer",
        #         ),
        #     ], name="pl_pid_emb_model"
        # )
        
        # Feature: description_pl
        self.pl_description_text_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.TextVectorization(
                    # max_tokens=len(vocab_dict["description_pl"]), # not needed if passing vocab
                    vocabulary=vocab_dict['description_pl'], 
                    name="description_pl_vectorizer", 
                    ngrams=2,
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict["description_pl"]),
                    output_dim=EMBEDDING_DIM,
                    mask_zero=False,
                    name="description_pl_emb_layer",
                ),
                tf.keras.layers.GlobalAveragePooling1D(name="description_pl_pooling"),
            ], name="pl_description_emb_model"
        )
        
        # Feature: duration_ms_seed_pl                      
        # TODO: Noramlize or Descritize?
        duration_ms_seed_pl_buckets = np.linspace(
            vocab_dict['min_duration_ms_seed_pl'], 
            vocab_dict['max_duration_ms_seed_pl'], 
            num=1000
        )
        self.duration_ms_seed_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(duration_ms_seed_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(duration_ms_seed_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM, 
                    name="duration_ms_seed_pl_emb_layer",
                )
            ], name="duration_ms_seed_pl_emb_model"
        )
        # self.duration_ms_seed_pl_normalization = tf.keras.layers.Normalization(
        #     mean=vocab_dict['avg_duration_ms_seed_pl'],
        #     variance=vocab_dict['var_duration_ms_seed_pl'],
        #     axis=None
        # )
        
        # Feature: n_songs_pl
        # TODO: Noramlize or Descritize?
        n_songs_pl_buckets = np.linspace(
            vocab_dict['min_n_songs_pl'], 
            vocab_dict['max_n_songs_pl'], 
            num=100
        )
        self.n_songs_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(n_songs_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(n_songs_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM, 
                    name="n_songs_pl_emb_layer",
                )
            ], name="n_songs_pl_emb_model"
        )
        # self.n_songs_pl_normalization = tf.keras.layers.Normalization(
        #     mean=vocab_dict['avg_n_songs_pl'],
        #     variance=vocab_dict['var_n_songs_pl'],
        #     axis=None
        # )
        
        # Feature: num_artists_pl
        # TODO: Noramlize or Descritize?
        n_artists_pl_buckets = np.linspace(
            vocab_dict['min_n_artists_pl'], 
            vocab_dict['max_n_artists_pl'], 
            num=100
        )
        self.n_artists_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(n_artists_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(n_artists_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM, 
                    name="n_artists_pl_emb_layer",
                )
            ], name="n_artists_pl_emb_model"
        )
        # self.n_artists_pl_normalization = tf.keras.layers.Normalization(
        #     mean=vocab_dict['avg_n_artists_pl'],
        #     variance=vocab_dict['var_n_artists_pl'],
        #     axis=None
        # )
        
        # Feature: num_albums_pl
        n_albums_pl_buckets = np.linspace(
            vocab_dict['min_n_albums_pl'], 
            vocab_dict['max_n_albums_pl'],
            num=100
        )
        self.n_albums_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(n_albums_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(n_albums_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM, 
                    name="n_albums_pl_emb_layer",
                )
            ], name="n_albums_pl_emb_model"
        )
        # self.n_albums_pl_normalization = tf.keras.layers.Normalization(
        #     mean=vocab_dict['avg_n_albums_pl'],
        #     variance=vocab_dict['var_n_albums_pl'],
        #     axis=None
        # )
        
        # ========================================
        # sequence playlist features
        # ========================================
        
        # Feature: artist_name_pl
        self.artist_name_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.StringLookup(
                    vocabulary=vocab_dict['artist_name_pl'], mask_token=''),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['artist_name_pl']) + 1, 
                    output_dim=EMBEDDING_DIM,
                    name="artist_name_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="artist_name_pl_emb_model"
        )
        
        # Feature: track_uri_pl
        # 2.2M unique
        self.track_uri_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Hashing(num_bins=200_000),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['track_uri_pl']) + 1, 
                    output_dim=EMBEDDING_DIM,
                    name="track_uri_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="track_uri_pl_emb_model"
        )
        
        # Feature: track_name_pl
        self.track_name_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.StringLookup(
                    vocabulary=vocab_dict['track_name_pl'], 
                    name="track_name_pl_lookup",
                    output_mode='int',
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['track_name_pl']), 
                    output_dim=EMBEDDING_DIM,
                    name="track_name_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="track_name_pl_emb_model"
        )
        
        # Feature: duration_ms_songs_pl
        duration_ms_songs_pl_buckets = np.linspace(
            vocab_dict['min_duration_ms_songs_pl'], 
            vocab_dict['max_duration_ms_songs_pl'], 
            num=100
        )
        self.duration_ms_songs_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(duration_ms_songs_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(duration_ms_songs_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM,
                    name="duration_ms_songs_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="duration_ms_songs_pl_emb_model"
        )
        
        # Feature: album_name_pl
        self.album_name_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.StringLookup(
                    vocabulary=vocab_dict['album_name_pl'], mask_token=None),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['album_name_pl']), 
                    output_dim=EMBEDDING_DIM,
                    name="album_name_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="album_name_pl_emb_model"
        )

        # Feature: artist_pop_pl
        artist_pop_pl_buckets = np.linspace(
            vocab_dict['min_artist_pop'], 
            vocab_dict['max_artist_pop'], 
            num=10
        )
        self.artist_pop_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(artist_pop_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(artist_pop_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM,
                    name="artist_pop_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="artist_pop_pl_emb_model"
        )
        
        # Feature: artists_followers_pl
        artists_followers_pl_buckets = np.linspace(
            vocab_dict['min_artist_followers'], 
            vocab_dict['max_artist_followers'], 
            num=10
        )
        self.artists_followers_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(artists_followers_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(artists_followers_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM,
                    name="artists_followers_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="artists_followers_pl_emb_model"
        )
        
        # Feature: track_pop_pl
        track_pop_pl_buckets = np.linspace(
            vocab_dict['min_track_pop'], 
            vocab_dict['max_track_pop'], 
            num=10
        )
        self.track_pop_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Discretization(track_pop_pl_buckets.tolist()),
                tf.keras.layers.Embedding(
                    input_dim=len(track_pop_pl_buckets) + 1, 
                    output_dim=EMBEDDING_DIM,
                    name="track_pop_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="track_pop_pl_emb_model"
        )
        
        # Feature: artist_genres_pl
        self.artist_genres_pl_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.StringLookup(
                    vocabulary=vocab_dict['artist_genres_pl'], mask_token=None),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['artist_genres_pl']), 
                    output_dim=EMBEDDING_DIM,
                    name="artist_genres_pl_emb_layer",
                ),
                tf.keras.layers.GRU(EMBEDDING_DIM),
            ], name="artist_genres_pl_emb_model"
        )

        # ========================================
        # dense and cross layers
        # ========================================

        # Cross Layers
        if USE_CROSS_LAYER:
            self._cross_layer = tfrs.layers.dcn.Cross(
                projection_dim=PROJECTION_DIM,
                kernel_initializer="glorot_uniform", 
                name="pl_cross_layer"
            )
        else:
            self._cross_layer = None
            
        # Dense Layers
        self.dense_layers = tf.keras.Sequential(name="pl_dense_layers")
        initializer = tf.keras.initializers.GlorotUniform(seed=SEED)
        
        # Use the ReLU activation for all but the last layer.
        for layer_size in layer_sizes[:-1]:
            self.dense_layers.add(
                tf.keras.layers.Dense(
                    layer_size, 
                    activation="relu", 
                    kernel_initializer=initializer,
                )
            )
            if DROPOUT:
                self.dense_layers.add(tf.keras.layers.Dropout(DROPOUT_RATE))
                
        # No activation for the last layer
        for layer_size in layer_sizes[-1:]:
            self.dense_layers.add(
                tf.keras.layers.Dense(
                    layer_size, 
                    kernel_initializer=initializer
                )
            )
        ### ADDING L2 NORM AT THE END
        self.dense_layers.add(
            tf.keras.layers.Lambda(
                lambda x: tf.nn.l2_normalize(
                    x, 1, epsilon=1e-12, name="normalize_dense"
                )
            )
        )
    # ========================================
    # call
    # ========================================
    def call(self, data):
        '''
        The call method defines what happens when
        the model is called
        '''
        
        all_embs = tf.concat(
            [
                self.pl_name_text_embedding(data['name']),
                self.pl_collaborative_embedding(data['collaborative']),
                # self.pl_pid_embedding(data["pid"]),
                self.pl_description_text_embedding(data['description_pl']),
                self.duration_ms_seed_pl_embedding(data["duration_ms_seed_pl"]),
                # tf.reshape(self.duration_ms_seed_pl_normalization(data["duration_ms_seed_pl"]), (-1, 1))      # Normalize or Discretize?
                self.n_songs_pl_embedding(data["n_songs_pl"]),
                # tf.reshape(self.n_songs_pl_normalization(data["n_songs_pl"]), (-1, 1))                        # Normalize or Discretize?
                self.n_artists_pl_embedding(data['num_artists_pl']),
                # tf.reshape(self.n_artists_pl_normalization(data["num_artists_pl"]), (-1, 1))                  # Normalize or Discretize?
                self.n_albums_pl_embedding(data["num_albums_pl"]),
                # tf.reshape(self.n_albums_pl_normalization(data["num_albums_pl"]), (-1, 1))                    # Normalize or Discretize?
                
                # sequence features
                # data["pos_pl"],
                self.artist_name_pl_embedding(data["artist_name_pl"]),
                self.track_uri_pl_embedding(data["track_uri_pl"]),
                self.track_name_pl_embedding(data["track_name_pl"]),
                self.duration_ms_songs_pl_embedding(data["duration_ms_songs_pl"]),
                self.album_name_pl_embedding(data["album_name_pl"]),
                self.artist_pop_pl_embedding(data["artist_pop_pl"]),
                self.artists_followers_pl_embedding(data["artists_followers_pl"]),
                self.track_pop_pl_embedding(data["track_pop_pl"]),
                self.artist_genres_pl_embedding(data["artist_genres_pl"]),
            ], axis=1)
        
        # Build Cross Network
        if self._cross_layer is not None:
            cross_embs = self._cross_layer(all_embs)
            return self.dense_layers(cross_embs)
        else:
            return self.dense_layers(all_embs)

# %%
layer_sizes=[64,32]

test_query_model = QueryModel(layer_sizes,vocab_dict_load)

pl_result = test_query_model(test_instance)

print(f"Shape of pl_result: {pl_result.shape}")
pl_result

# %% [markdown]
# ## Candidate Tower

# %%
for x in parsed_candidate_ds.take(1).as_numpy_iterator():
    pprint(x['artist_genres'])
# Out:
# array([b"'compositional ambient', 'neo-classical'"], dtype=object)

# %%
can_test_instance = {
    'artist_name': np.asarray([b'Fabrizio Paterlini']),
    'track_name': np.asarray([b"Controvento, senz'olio"]),
    'album_name' : np.asarray([b'Fragments Found']),
    'track_uri' : np.asarray([b'spotify:track:78KGo61bPbtgSqFnIuhQbZ']),
    'artist_uri' : np.asarray([b'spotify:artist:0jrFMgW018F1XVnLtCXOKi']),
    'album_uri' : np.asarray([b'spotify:album:39LWVcWN0HG7SF27UiuW9b']),
    'duration_ms' : np.asarray([222747]),
    'track_pop' : np.asarray([28]),
    'artist_pop' : np.asarray([69.0]),
    'artist_followers' : np.asarray([90784.0]),
    'artist_genres' : np.asarray([b"'compositional ambient', 'neo-classical'"]),
}
pprint(can_test_instance)
# Out:
# {'album_name': array([b'Fragments Found'], dtype='|S15'),
#  'album_uri': array([b'spotify:album:39LWVcWN0HG7SF27UiuW9b'], dtype='|S36'),
#  'artist_followers': array([90784.]),
#  'artist_genres': array([b"'compositional ambient', 'neo-classical'"], dtype='|S40'),
#  'artist_name': array([b'Fabrizio Paterlini'], dtype='|S18'),
#  'artist_pop': array([69.]),
#  'artist_uri': array([b'spotify:artist:0jrFMgW018F1XVnLtCXOKi'], dtype='|S37'),
#  'duration_ms': array([222747]),
#  'track_name': array([b"Controvento, senz'olio"], dtype='|S22'),
#  'track_pop': array([28]),
#  'track_uri': array([b'spotify:track:78KGo61bPbtgSqFnIuhQbZ'], dtype='|S36')}

# %%
EMBEDDING_DIM = 32
PROJECTION_DIM = 5
SEED = 1234
USE_CROSS_LAYER=True
DROPOUT='False'
DROPOUT_RATE='0.33'

class CandidateModel(tf.keras.Model):
    def __init__(self, layer_sizes, vocab_dict):
        super().__init__()
        
        # ========================================
        # Candidate features
        # ========================================
        
        # Feature: artist_name_can
        self.artist_name_text_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.TextVectorization(
                    vocabulary=vocab_dict["artist_name_can"],
                    name="artist_name_txt_vectorizer",
                    ngrams=2,
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict["artist_name_can"]),
                    output_dim=EMBEDDING_DIM,
                    mask_zero=False,
                    name="artist_name_emb_layer",
                ),
                tf.keras.layers.GlobalAveragePooling1D(name="artist_name_pooling"),
            ], name="artist_name_emb_model"
        )

        # Feature: track_name_can
        self.track_name_text_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.TextVectorization(
                    vocabulary=vocab_dict["track_name_can"],
                    name="track_name_txt_vectorizer",
                    ngrams=2,
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict["track_name_can"]),
                    output_dim=EMBEDDING_DIM,
                    mask_zero=False,
                    name="track_name_emb_layer",
                ),
                tf.keras.layers.GlobalAveragePooling1D(name="track_name_pooling"),
            ], name="track_name_emb_model"
        )
        
        # Feature: album_name_can
        self.album_name_text_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.TextVectorization(
                    vocabulary=vocab_dict["album_name_can"],
                    name="album_name_txt_vectorizer",
                    ngrams=2,
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict["album_name_can"]),
                    output_dim=EMBEDDING_DIM,
                    mask_zero=False,
                    name="album_name_emb_layer",
                ),
                tf.keras.layers.GlobalAveragePooling1D(name="album_name_pooling"),
            ], name="album_name_emb_model"
        )
        
        # Feature: artist_uri_can
        self.artist_uri_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Hashing(num_bins=200_000),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['artist_uri_can']), 
                    output_dim=EMBEDDING_DIM,
                    name="artist_uri_emb_layer",
                ),
            ], name="artist_uri_emb_model"
        )
        
        # Feature: track_uri_can
        self.track_uri_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Hashing(num_bins=200_000),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['track_uri_can']), 
                    output_dim=EMBEDDING_DIM,
                    name="track_uri_emb_layer",
                ),
            ], name="track_uri_emb_model"
        )
        
        # Feature: album_uri_can
        self.album_uri_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.Hashing(num_bins=200_000),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict['album_uri_can']), 
                    output_dim=EMBEDDING_DIM,
                    name="album_uri_emb_layer",
                ),
            ], name="album_uri_emb_model"
        )
        
        # Feature: duration_ms_can
        self.duration_ms_normalized = tf.keras.layers.Normalization(
            mean=vocab_dict['avg_duration_ms_songs_pl'],
            variance=vocab_dict['var_duration_ms_songs_pl'],
            axis=None
        )
        
        # Feature: track_pop_can
        self.track_pop_normalized = tf.keras.layers.Normalization(
            mean=vocab_dict['avg_track_pop'],
            variance=vocab_dict['var_track_pop'],
            axis=None
        )
        
        # Feature: artist_pop_can
        self.artist_pop_normalized = tf.keras.layers.Normalization(
            mean=vocab_dict['avg_artist_pop'],
            variance=vocab_dict['var_artist_pop'],
            axis=None
        )
        
        # Feature: artist_followers_can
        self.artist_followers_normalized = tf.keras.layers.Normalization(
            mean=vocab_dict['avg_artist_followers'],
            variance=vocab_dict['var_artist_followers'],
            axis=None
        )
        
        # Feature: artist_genres_can
        self.artist_genres_text_embedding = tf.keras.Sequential(
            [
                tf.keras.layers.TextVectorization(
                    vocabulary=vocab_dict["artist_genres_can"],
                    name="artist_genres_txt_vectorizer",
                    ngrams=2,
                ),
                tf.keras.layers.Embedding(
                    input_dim=len(vocab_dict["artist_genres_can"]),
                    output_dim=EMBEDDING_DIM,
                    mask_zero=False,
                    name="artist_genres_emb_layer",
                ),
                tf.keras.layers.GlobalAveragePooling1D(name="artist_genres_pooling"),
            ], name="artist_genres_emb_model"
        )
        # ========================================
        # Dense & Cross Layers
        # ========================================
        
        # Cross Layers
        
        # Dense Layer
        self.dense_layers = tf.keras.Sequential(name="candidate_dense_layers")
        initializer = tf.keras.initializers.GlorotUniform(seed=SEED)
        
        # Use the ReLU activation for all but the last layer.
        for layer_size in layer_sizes[:-1]:
            self.dense_layers.add(
                tf.keras.layers.Dense(
                    layer_size, 
                    activation="relu", 
                    kernel_initializer=initializer,
                )
            )
            if DROPOUT:
                self.dense_layers.add(tf.keras.layers.Dropout(DROPOUT_RATE))
                
        # No activation for the last layer
        for layer_size in layer_sizes[-1:]:
            self.dense_layers.add(
                tf.keras.layers.Dense(
                    layer_size, 
                    kernel_initializer=initializer
                )
            )
            
    # ========================================
    # Call Function
    # ========================================
            
    def call(self, data):
        
        all_embs = tf.concat(
            [
                self.artist_name_text_embedding(data['artist_name']),
                self.track_name_text_embedding(data['track_name']),
                self.album_name_text_embedding(data['album_name']),
                self.artist_uri_embedding(data['artist_uri']),
                self.track_uri_embedding(data['track_uri']),
                self.album_uri_embedding(data['album_uri']),
                tf.reshape(self.duration_ms_normalized(data["duration_ms"]), (-1, 1)),
                tf.reshape(self.track_pop_normalized(data["track_pop"]), (-1, 1)),
                tf.reshape(self.artist_pop_normalized(data["artist_pop"]), (-1, 1)),
                tf.reshape(self.artist_followers_normalized(data["artist_followers"]), (-1, 1)),
                self.artist_genres_text_embedding(data['artist_genres']),
            ], axis=1
        )
        
        return self.dense_layers(all_embs)

# %%
layer_sizes=[64,32]

test_can_track_model = CandidateModel(layer_sizes, vocab_dict_load)

can_result = test_can_track_model(can_test_instance)

print(f"Shape of can_result: {can_result.shape}")
can_result
# Out:
# Shape of can_result: (1, 32)
# <tf.Tensor: shape=(1, 32), dtype=float32, numpy=
# array([[ 0.09066525, -0.0329502 , -0.15642835,  0.14253873, -0.22031482,
#         -0.20585833,  0.00237853,  0.09689148, -0.23827414,  0.07929395,
#          0.1594544 , -0.3280748 , -0.05949891,  0.323694  ,  0.0431367 ,
#          0.51964384,  0.00217604, -0.19773087,  0.66890687, -0.25335404,
#          0.13731247, -0.22903056,  0.00915089,  0.12287275,  0.15709822,
#         -0.08462201,  0.33281654, -0.3906095 ,  0.21985911, -0.26035348,
#         -0.21582597,  0.17136298]], dtype=float32)>

# %%
test_can_track_model.summary(expand_nested=True)
# Out:
# Model: "candidate_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  artist_name_emb_model (Sequ  (None, 32)               9206720
#  ential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | artist_name_txt_vectorizer   (None, None)           0         |
# | (TextVectorization)                                           |
# |                                                               |
# | artist_name_emb_layer (Embe  (None, None, 32)       9206720   |
# | dding)                                                        |
# |                                                               |
# | artist_name_pooling (Global  (None, 32)             0         |
# | AveragePooling1D)                                             |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  track_name_emb_model (Seque  (None, 32)               47480096
#  ntial)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | track_name_txt_vectorizer (  (None, None)           0         |
# | TextVectorization)                                            |
# |                                                               |
# | track_name_emb_layer (Embed  (None, None, 32)       47480096  |
# | ding)                                                         |
# |                                                               |
# | track_name_pooling (GlobalA  (None, 32)             0         |
# | veragePooling1D)                                              |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  album_name_emb_model (Seque  (None, 32)               18292000
#  ntial)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | album_name_txt_vectorizer (  (None, None)           0         |
# | TextVectorization)                                            |
# |                                                               |
# | album_name_emb_layer (Embed  (None, None, 32)       18292000  |
# | ding)                                                         |
# |                                                               |
# | album_name_pooling (GlobalA  (None, 32)             0         |
# | veragePooling1D)                                              |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  artist_uri_emb_model (Seque  (1, 32)                  9467520
#  ntial)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | hashing_6 (Hashing)       (1,)                      0         |
# |                                                               |
# | artist_uri_emb_layer (Embed  (1, 32)                9467520   |
# | ding)                                                         |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  track_uri_emb_model (Sequen  (1, 32)                  72393344
#  tial)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | hashing_7 (Hashing)       (1,)                      0         |
# |                                                               |
# | track_uri_emb_layer (Embedd  (1, 32)                72393344  |
# | ing)                                                          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  album_uri_emb_model (Sequen  (1, 32)                  23509888
#  tial)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | hashing_8 (Hashing)       (1,)                      0         |
# |                                                               |
# | album_uri_emb_layer (Embedd  (1, 32)                23509888  |
# | ing)                                                          |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  normalization_4 (Normalizat  multiple                 0
#  ion)
#
#  normalization_5 (Normalizat  multiple                 0
#  ion)
#
#  normalization_6 (Normalizat  multiple                 0
#  ion)
#
#  normalization_7 (Normalizat  multiple                 0
#  ion)
#
#  artist_genres_emb_model (Se  (None, 32)               1260704
#  quential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | artist_genres_txt_vectorize  (None, None)           0         |
# | r (TextVectorization)                                         |
# |                                                               |
# | artist_genres_emb_layer (Em  (None, None, 32)       1260704   |
# | bedding)                                                      |
# |                                                               |
# | artist_genres_pooling (Glob  (None, 32)             0         |
# | alAveragePooling1D)                                           |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  candidate_dense_layers (Seq  (1, 32)                  16736
#  uential)
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | dense_4 (Dense)           (1, 64)                   14656     |
# |                                                               |
# | dropout_2 (Dropout)       (1, 64)                   0         |
# |                                                               |
# | dense_5 (Dense)           (1, 32)                   2080      |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
# =================================================================
# Total params: 181,627,008
# Trainable params: 181,627,008
# Non-trainable params: 0
# _________________________________________________________________

# %%
for raw_record in raw_train_ds.take(5):
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())
    print(example)
# Out:
# features {
#   feature {
#     key: "album_name_can"
#     value {
#       bytes_list {
#         value: "Glee: The Music, The Complete Season Three"
#       }
#     }
#   }
#   feature {
#     key: "album_name_pl"
#     value {
#       bytes_list {
#         value: "Glee: The Music, The Complete Season One"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music presents Glease"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season One"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season One"
#         value: "Glee: The Music, Volume 2"
#         value: "Glee: The Music, Volume 1"
#         value: "Glee: The Music, Volume 1"
#         value: "Glee: The Music, Volume 1"
#         value: "Glee: The Music, The Complete Season One"
#         value: "Glee: The Music presents Glease"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season One"
#         value: "Glee: The Music, The Complete Season Two"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Three"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season One"
#         value: "Glee: The Music, Season 4 Volume 1"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#         value: "Glee: The Music, The Complete Season Four"
#       }
#     }
#   }
#   feature {
#     key: "album_name_seed_track"
#     value {
#       bytes_list {
#         value: "Glee: The Music, The Complete Season Four"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:album:082BH67sSIDefLxUp8GgNm"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:album:4fZXOp8No89WLudGy6brXd"
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_can"
#     value {
#       float_list {
#         value: 1452611.0
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_seed_track"
#     value {
#       float_list {
#         value: 1452611.0
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_can"
#     value {
#       bytes_list {
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_pl"
#     value {
#       bytes_list {
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_seed_track"
#     value {
#       bytes_list {
#         value: "\'glee club\', \'hollywood\', \'post-teen pop\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_can"
#     value {
#       bytes_list {
#         value: "Glee Cast"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_pl"
#     value {
#       bytes_list {
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#         value: "Glee Cast"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_seed_track"
#     value {
#       bytes_list {
#         value: "Glee Cast"
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_can"
#     value {
#       float_list {
#         value: 76.0
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_pl"
#     value {
#       float_list {
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#         value: 76.0
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_seed_track"
#     value {
#       float_list {
#         value: 76.0
#       }
#     }
#   }
#   feature {
#     key: "artist_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:artist:0SCbttzoZTnLFebDYmAWCm"
#       }
#     }
#   }
#   feature {
#     key: "artist_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:artist:0SCbttzoZTnLFebDYmAWCm"
#       }
#     }
#   }
#   feature {
#     key: "artists_followers_pl"
#     value {
#       float_list {
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#         value: 1452611.0
#       }
#     }
#   }
#   feature {
#     key: "collaborative"
#     value {
#       bytes_list {
#         value: "false"
#       }
#     }
#   }
#   feature {
#     key: "description_pl"
#     value {
#       bytes_list {
#         value: ""
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_can"
#     value {
#       float_list {
#         value: 285493.0
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_playlist"
#     value {
#       int64_list {
#         value: 25266682
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_seed_pl"
#     value {
#       float_list {
#         value: 10529275.0
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_songs_pl"
#     value {
#       float_list {
#         value: 187413.0
#         value: 246853.0
#         value: 161320.0
#         value: 197853.0
#         value: 225266.0
#         value: 257493.0
#         value: 209786.0
#         value: 187666.0
#         value: 211946.0
#         value: 193560.0
#         value: 230573.0
#         value: 168746.0
#         value: 169426.0
#         value: 170706.0
#         value: 322933.0
#         value: 230573.0
#         value: 262866.0
#         value: 213413.0
#         value: 226693.0
#         value: 183293.0
#         value: 217400.0
#         value: 183386.0
#         value: 237573.0
#         value: 194466.0
#         value: 219693.0
#         value: 266760.0
#         value: 125013.0
#         value: 221466.0
#         value: 117121.0
#         value: 243809.0
#         value: 283654.0
#         value: 206200.0
#         value: 163173.0
#         value: 250973.0
#         value: 111333.0
#         value: 221360.0
#         value: 226853.0
#         value: 181200.0
#         value: 246186.0
#         value: 232760.0
#         value: 167800.0
#         value: 228973.0
#         value: 216440.0
#         value: 222413.0
#         value: 227400.0
#         value: 122293.0
#         value: 169333.0
#         value: 177213.0
#         value: 181720.0
#         value: 226733.0
#         value: 180200.0
#       }
#     }
#   }
#   feature {
#     key: "duration_seed_track"
#     value {
#       float_list {
#         value: 180200.0
#       }
#     }
#   }
#   feature {
#     key: "modified_at"
#     value {
#       int64_list {
#         value: 1494028800
#       }
#     }
#   }
#   feature {
#     key: "n_songs_pl"
#     value {
#       float_list {
#         value: 51.0
#       }
#     }
#   }
#   feature {
#     key: "name"
#     value {
#       bytes_list {
#         value: "love"
#       }
#     }
#   }
#   feature {
#     key: "num_albums_pl"
#     value {
#       float_list {
#         value: 8.0
#       }
#     }
#   }
#   feature {
#     key: "num_artists_pl"
#     value {
#       float_list {
#         value: 1.0
#       }
#     }
#   }
#   feature {
#     key: "pid"
#     value {
#       int64_list {
#         value: 199936
#       }
#     }
#   }
#   feature {
#     key: "pid_pos_id"
#     value {
#       bytes_list {
#         value: "199936-51"
#       }
#     }
#   }
#   feature {
#     key: "pos_can"
#     value {
#       int64_list {
#         value: 51
#       }
#     }
#   }
#   feature {
#     key: "pos_pl"
#     value {
#       int64_list {
#         value: 0
#         value: 1
#         value: 2
#         value: 3
#         value: 4
#         value: 5
#         value: 6
#         value: 7
#         value: 8
#         value: 9
#         value: 10
#         value: 11
#         value: 12
#         value: 13
#         value: 14
#         value: 15
#         value: 16
#         value: 17
#         value: 18
#         value: 19
#         value: 20
#         value: 21
#         value: 22
#         value: 23
#         value: 24
#         value: 25
#         value: 26
#         value: 27
#         value: 28
#         value: 29
#         value: 30
#         value: 31
#         value: 32
#         value: 33
#         value: 34
#         value: 35
#         value: 36
#         value: 37
#         value: 38
#         value: 39
#         value: 40
#         value: 41
#         value: 42
#         value: 43
#         value: 44
#         value: 45
#         value: 46
#         value: 47
#         value: 48
#         value: 49
#         value: 50
#       }
#     }
#   }
#   feature {
#     key: "pos_seed_track"
#     value {
#       int64_list {
#         value: 50
#       }
#     }
#   }
#   feature {
#     key: "row_number"
#     value {
#       int64_list {
#         value: 1
#       }
#     }
#   }
#   feature {
#     key: "track_name_can"
#     value {
#       bytes_list {
#         value: "You Get What You Give (Glee Cast Version)"
#       }
#     }
#   }
#   feature {
#     key: "track_name_pl"
#     value {
#       bytes_list {
#         value: "Any Way You Want It / Lovin\' Touchin\' Squeezin\' (Glee Cast Version)"
#         value: "Man In The Mirror (Glee Cast Version)"
#         value: "I Can\'t Go For That / You Make My Dreams (Glee Cast Version)"
#         value: "Sexy And I Know It (Glee Cast Version featuring Ricky Martin)"
#         value: "Only The Good Die Young (Glee Cast Version)"
#         value: "Love Song (Glee Cast Version)"
#         value: "Stop! In The Name Of Love / Free Your Mind (Glee Cast Version)"
#         value: "Lucky (Glee Cast Version)"
#         value: "Billionaire (Glee Cast Version)"
#         value: "Greased Lightning (Glee Cast Version)"
#         value: "Locked Out Of Heaven (Glee Cast Version)"
#         value: "No Scrubs (Glee Cast Version)"
#         value: "Bye Bye Bye / I Want It That Way (Glee Cast Version)"
#         value: "Start Me Up / Livin\' On A Prayer (Glee Cast Version)"
#         value: "It\'s All Coming Back To Me Now (Glee Cast Version)"
#         value: "Paradise By The Dashboard Light (Glee Cast Version)"
#         value: "Edge Of Glory (Glee Cast Version)"
#         value: "Valerie - Glee Cast Version"
#         value: "Don\'t Stop Believin\' (Glee Cast - Rachel/Lea Michele solo audition version)"
#         value: "Singing In The Rain / Umbrella (Glee Cast Version featuring Gwyneth Paltrow)"
#         value: "Need You Now (Glee Cast Version)"
#         value: "Hungry Like The Wolf / Rio (Glee Cast Version)"
#         value: "I Just Can\'t Stop Loving You (Glee Cast Version)"
#         value: "Jessie\'s Girl (Glee Cast Version)"
#         value: "Don\'t Go Breaking My Heart (Glee Cast Version)"
#         value: "The Only Exception (Glee Cast Version)"
#         value: "Halo / Walking On Sunshine (Glee Cast Version)"
#         value: "Proud Mary (Glee Cast Version)"
#         value: "Sweet Caroline (Glee Cast Version)"
#         value: "Keep Holding On (Glee Cast Version)"
#         value: "Somebody To Love (Glee Cast Version) - Cover of Queen Song"
#         value: "Rehab (Glee Cast Version)"
#         value: "Born To Hand Jive (Glee Cast Version)"
#         value: "Holding Out For A Hero (Glee Cast Version)"
#         value: "It\'s My Life / Confessions Part II (Glee Cast Version)"
#         value: "Forget You (Glee Cast Version featuring Gwyneth Paltrow)"
#         value: "Whistle (Glee Cast Version)"
#         value: "Uptown Girl (Glee Cast Version)"
#         value: "Somebody That I Used To Know (Glee Cast Version)"
#         value: "My Prerogative (Glee Cast Version)"
#         value: "Wannabe (Glee Cast Version)"
#         value: "Wake Me Up Before You Go-Go (Glee Cast Version)"
#         value: "Cold Hearted (Glee Cast Version)"
#         value: "How To Be A Heartbreaker (Glee Cast Version)"
#         value: "Footloose (Glee Cast Version)"
#         value: "Old Time Rock & Roll / Danger Zone (Glee Cast Version)"
#         value: "Shout It Out Loud (Glee Cast Version)"
#         value: "Let\'s Have A Kiki (Glee Cast Version featuring Sarah Jessica Parker)"
#         value: "Nutbush City Limits (Glee Cast Version)"
#         value: "Don\'t Dream It\'s Over (Glee Cast Version)"
#         value: "Come See About Me (Glee Cast Version)"
#       }
#     }
#   }
#   feature {
#     key: "track_name_seed_track"
#     value {
#       bytes_list {
#         value: "Come See About Me (Glee Cast Version)"
#       }
#     }
#   }
#   feature {
#     key: "track_pop_can"
#     value {
#       float_list {
#         value: 27.0
#       }
#     }
#   }
#   feature {
#     key: "track_pop_pl"
#     value {
#       float_list {
#         value: 39.0
#         value: 31.0
#         value: 43.0
#         value: 41.0
#         value: 38.0
#         value: 49.0
#         value: 45.0
#         value: 35.0
#         value: 33.0
#         value: 44.0
#         value: 48.0
#         value: 46.0
#         value: 47.0
#         value: 51.0
#         value: 58.0
#         value: 54.0
#         value: 35.0
#         value: 38.0
#         value: 44.0
#         value: 54.0
#         value: 35.0
#         value: 42.0
#         value: 32.0
#         value: 54.0
#         value: 40.0
#         value: 32.0
#         value: 55.0
#         value: 46.0
#         value: 51.0
#         value: 54.0
#         value: 54.0
#         value: 40.0
#         value: 44.0
#         value: 33.0
#         value: 54.0
#         value: 34.0
#         value: 49.0
#         value: 37.0
#         value: 52.0
#         value: 39.0
#         value: 47.0
#         value: 47.0
#         value: 50.0
#         value: 48.0
#         value: 56.0
#         value: 44.0
#         value: 31.0
#         value: 44.0
#         value: 49.0
#         value: 46.0
#         value: 43.0
#       }
#     }
#   }
#   feature {
#     key: "track_pop_seed_track"
#     value {
#       float_list {
#         value: 43.0
#       }
#     }
#   }
#   feature {
#     key: "track_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:track:6KhJeYLg1AimCQjH6ii1Al"
#       }
#     }
#   }
#   feature {
#     key: "track_uri_pl"
#     value {
#       bytes_list {
#         value: "spotify:track:3oi10LN6bDwIp7yjqatJxR"
#         value: "spotify:track:4WLd3bP9gS39YaOQ7OX2Rg"
#         value: "spotify:track:2zgQMaosCMcPKjxs9QQfte"
#         value: "spotify:track:3hTHfK1PVAPgZ8aU1eqbfT"
#         value: "spotify:track:5FwMr2Grj9SjbUYp04dk5k"
#         value: "spotify:track:2JMn8khlzTaqMHzs5R8XpF"
#         value: "spotify:track:3s3GGkQwwQZq1HOsAjLkK1"
#         value: "spotify:track:0I1ruLjzvn6M3Rl6g5CzP2"
#         value: "spotify:track:4ZuoXgmimVO95BU0GzgCOG"
#         value: "spotify:track:1Oh2gDRhx4EYkCAz9tg2Ze"
#         value: "spotify:track:00ZROeHf7xvMw5q8wAYf9O"
#         value: "spotify:track:4KbE727f0rcKFw561OKhyg"
#         value: "spotify:track:3vwTNVxHRpRw9Jr4RT7HJF"
#         value: "spotify:track:2b93fpnWgsXmmnCBKZ86nu"
#         value: "spotify:track:6SluKjEbTkN9eUn6C4Qzh0"
#         value: "spotify:track:51mRyXsvuQD3DIzfzw6Xcj"
#         value: "spotify:track:4D5zQtamimbYqbkjPq8wIV"
#         value: "spotify:track:7aazto5pmbOWKN9ra7z84N"
#         value: "spotify:track:55dt0NxRCgNctRv9cqKGeB"
#         value: "spotify:track:1v3RJ3mtHllca29JVi12OB"
#         value: "spotify:track:4bL1fgBPnsaqow8p4VdWzB"
#         value: "spotify:track:0BEiDA0JOycXaDI5ynEWgz"
#         value: "spotify:track:6HYyXPpdoNb6eMnN6EKRzD"
#         value: "spotify:track:3aKNGl01j8n9RZY7XHWPMz"
#         value: "spotify:track:6nPJX6ZzBr3TnztKo0UXYw"
#         value: "spotify:track:7Kq09t8UXNrLBV9ix6UHv4"
#         value: "spotify:track:2RF6eSUY1uOWaQjIC4rAFb"
#         value: "spotify:track:0BPrYI9uFyuI4WKmDx42q1"
#         value: "spotify:track:00dhuugTq7XaBohK71vN48"
#         value: "spotify:track:36EjGAZQMh8QFx7gdESSgr"
#         value: "spotify:track:43wOnyLJcwYfKVNxXZWPDz"
#         value: "spotify:track:3x0rTsHxeTWLHtVQT8sh1f"
#         value: "spotify:track:6ihcKg7L1TxDtwajts0m7o"
#         value: "spotify:track:4ys8xXjO7Myr5vy76j6Jf5"
#         value: "spotify:track:1NdBLNUZSEpBEITAt08ZmM"
#         value: "spotify:track:33fv4ibkF0Fd3sTRa9QfvI"
#         value: "spotify:track:4SZM5Rj0bWylIUvkuFswiy"
#         value: "spotify:track:0P3TbJLI2Cb6EQbp4NoAYy"
#         value: "spotify:track:5cxq7YCarud9twaVh6Y3Rt"
#         value: "spotify:track:6yZPH8UBeRanr0yPxK6O5g"
#         value: "spotify:track:56i0pQMTaM9Hq1gvjF9p9m"
#         value: "spotify:track:17vvsRxWjU6iK2KFPANn6h"
#         value: "spotify:track:6fAt0M805j9gjy1GSHwGdA"
#         value: "spotify:track:6dzsxLVeCTnp7oLXOnvoG3"
#         value: "spotify:track:2qzAQ81W0CvZqmhK8BYGLe"
#         value: "spotify:track:2Kj1TJZfOwowKtsCbrTtoc"
#         value: "spotify:track:6jkpgG6GTsg5XvXpvrUrzy"
#         value: "spotify:track:0HTkXoTQTsWLKlVwvPQ0DO"
#         value: "spotify:track:24frRMh10yF8HIqLgiiPKP"
#         value: "spotify:track:1N5sSLpAnV1hH3M5sB0UEK"
#         value: "spotify:track:3SFSSzmX9h0dVXEHCnzq8j"
#       }
#     }
#   }
#   feature {
#     key: "track_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:track:3SFSSzmX9h0dVXEHCnzq8j"
#       }
#     }
#   }
# }
#
# features {
#   feature {
#     key: "album_name_can"
#     value {
#       bytes_list {
#         value: "Bobby Tarantino"
#       }
#     }
#   }
#   feature {
#     key: "album_name_pl"
#     value {
#       bytes_list {
#         value: "The Original High"
#         value: "Full Speed"
#         value: "SremmLife 2"
#         value: "SremmLife"
#         value: "us"
#         value: "The Martin Garrix Collection"
#         value: "Dark Sky Paradise"
#         value: "F\303\251nix"
#         value: "T R A P S O U L"
#         value: "Trigga"
#         value: "Cloud Nine"
#         value: "Lukas Graham (Blue Album)"
#         value: "Cloud Nine"
#         value: "F\303\251nix"
#         value: "Late Nights: The Album"
#         value: "Trigga Reloaded"
#         value: "The Blueprint 3"
#         value: "Stoney"
#         value: "So Far Gone"
#         value: "Curtain Call"
#         value: "808s & Heartbreak"
#         value: "The Chainsmokers- Japan Special Edition"
#         value: "How Deep Is Your Love"
#         value: "Oxymoron"
#         value: "Ultimate"
#         value: "New English"
#         value: "2014 Forest Hills Drive"
#         value: "Word Of Mouf"
#         value: "Late Nights: The Album"
#         value: "2001"
#         value: "2001"
#         value: "2001"
#         value: "Back To Back"
#         value: "Views"
#         value: "Dum Dee Dum"
#         value: "Dubstep, Vol. 8"
#         value: "Dubstep, Vol. 7"
#         value: "Dubstep, Vol. 7"
#         value: "Plata O Plomo"
#         value: "Bobby Tarantino"
#       }
#     }
#   }
#   feature {
#     key: "album_name_seed_track"
#     value {
#       bytes_list {
#         value: "Bobby Tarantino"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:album:0WMr3ulx5Mzi1B3C8LsHVA"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:album:0WMr3ulx5Mzi1B3C8LsHVA"
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_can"
#     value {
#       float_list {
#         value: 5661726.0
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_seed_track"
#     value {
#       float_list {
#         value: 5661726.0
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_can"
#     value {
#       bytes_list {
#         value: "\'conscious hip hop\', \'dmv rap\', \'hip hop\', \'pop rap\', \'rap\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_pl"
#     value {
#       bytes_list {
#         value: "\'dance pop\', \'idol\', \'pop\', \'post-teen pop\'"
#         value: "\'dance pop\', \'hip hop\', \'pop rap\', \'rap\', \'southern hip hop\', \'trap\'"
#         value: "\'hip hop\', \'melodic rap\', \'mississippi hip hop\', \'pop rap\', \'rap\', \'southern hip hop\', \'trap\'"
#         value: "\'hip hop\', \'melodic rap\', \'mississippi hip hop\', \'pop rap\', \'rap\', \'southern hip hop\', \'trap\'"
#         value: "\'electropop\', \'pop\', \'pop rap\'"
#         value: "\'dance pop\', \'dutch edm\', \'edm\', \'pop\', \'pop dance\', \'progressive house\', \'tropical house\'"
#         value: "\'detroit hip hop\', \'hip hop\', \'pop\', \'pop rap\', \'rap\', \'southern hip hop\', \'trap\'"
#         value: "\'latin\', \'latin hip hop\', \'reggaeton\', \'trap latino\'"
#         value: "\'kentucky hip hop\', \'pop\', \'pop rap\', \'r&b\', \'rap\'"
#         value: "\'dance pop\', \'hip pop\', \'pop\', \'r&b\', \'southern hip hop\', \'trap\', \'urban contemporary\'"
#         value: "\'edm\', \'pop\', \'pop dance\', \'tropical house\'"
#         value: "\'danish pop\', \'pop\', \'scandipop\'"
#         value: "\'edm\', \'pop\', \'pop dance\', \'tropical house\'"
#         value: "\'latin\', \'latin hip hop\', \'reggaeton\', \'trap latino\'"
#         value: "\'chicago rap\', \'dance pop\', \'pop\', \'pop rap\', \'r&b\', \'southern hip hop\', \'trap\', \'urban contemporary\'"
#         value: "\'dance pop\', \'hip pop\', \'pop\', \'r&b\', \'southern hip hop\', \'trap\', \'urban contemporary\'"
#         value: "\'east coast hip hop\', \'hip hop\', \'rap\'"
#         value: "\'dfw rap\', \'melodic rap\', \'rap\'"
#         value: "\'canadian hip hop\', \'canadian pop\', \'hip hop\', \'rap\', \'toronto rap\'"
#         value: "\'detroit hip hop\', \'hip hop\', \'rap\'"
#         value: "\'chicago rap\', \'rap\'"
#         value: "\'dance pop\', \'edm\', \'electropop\', \'pop\', \'pop dance\', \'tropical house\'"
#         value: "\'dance pop\', \'edm\', \'electro house\', \'house\', \'pop\', \'pop dance\', \'pop rap\', \'progressive house\', \'uk dance\'"
#         value: "\'gangster rap\', \'hip hop\', \'pop rap\', \'rap\', \'southern hip hop\', \'trap\', \'underground hip hop\'"
#         value: "\'dark trap\', \'drill\', \'hip hop\', \'miami hip hop\', \'rap\', \'underground hip hop\'"
#         value: "\'pop rap\', \'rap\', \'southern hip hop\', \'trap\', \'viral trap\'"
#         value: "\'conscious hip hop\', \'hip hop\', \'north carolina hip hop\', \'rap\'"
#         value: "\'atl hip hop\', \'dirty south rap\', \'pop rap\', \'southern hip hop\'"
#         value: "\'chicago rap\', \'dance pop\', \'pop\', \'pop rap\', \'r&b\', \'southern hip hop\', \'trap\', \'urban contemporary\'"
#         value: "\'g funk\', \'gangster rap\', \'hip hop\', \'rap\', \'west coast rap\'"
#         value: "\'g funk\', \'gangster rap\', \'hip hop\', \'rap\', \'west coast rap\'"
#         value: "\'g funk\', \'gangster rap\', \'hip hop\', \'rap\', \'west coast rap\'"
#         value: "\'canadian hip hop\', \'canadian pop\', \'hip hop\', \'rap\', \'toronto rap\'"
#         value: "\'canadian hip hop\', \'canadian pop\', \'hip hop\', \'rap\', \'toronto rap\'"
#         value: "\'bass trap\', \'edm\', \'electro house\', \'electronic trap\', \'livetronica\', \'vapor twitch\'"
#         value: ""
#         value: ""
#         value: ""
#         value: "\'bronx hip hop\', \'east coast hip hop\', \'gangster rap\', \'hardcore hip hop\', \'hip hop\', \'hip pop\', \'pop rap\', \'rap\', \'trap\'"
#         value: "\'conscious hip hop\', \'dmv rap\', \'hip hop\', \'pop rap\', \'rap\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_seed_track"
#     value {
#       bytes_list {
#         value: "\'conscious hip hop\', \'dmv rap\', \'hip hop\', \'pop rap\', \'rap\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_can"
#     value {
#       bytes_list {
#         value: "Logic"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_pl"
#     value {
#       bytes_list {
#         value: "Adam Lambert"
#         value: "Kid Ink"
#         value: "Rae Sremmurd"
#         value: "Rae Sremmurd"
#         value: "gnash"
#         value: "Martin Garrix"
#         value: "Big Sean"
#         value: "Nicky Jam"
#         value: "Bryson Tiller"
#         value: "Trey Songz"
#         value: "Kygo"
#         value: "Lukas Graham"
#         value: "Kygo"
#         value: "Nicky Jam"
#         value: "Jeremih"
#         value: "Trey Songz"
#         value: "JAY Z"
#         value: "Post Malone"
#         value: "Drake"
#         value: "Eminem"
#         value: "Kanye West"
#         value: "The Chainsmokers"
#         value: "Calvin Harris"
#         value: "ScHoolboy Q"
#         value: "Denzel Curry"
#         value: "Desiigner"
#         value: "J. Cole"
#         value: "Disturbing Tha Peace"
#         value: "Jeremih"
#         value: "Dr. Dre"
#         value: "Dr. Dre"
#         value: "Dr. Dre"
#         value: "Drake"
#         value: "Drake"
#         value: "Keys N Krates"
#         value: "DJ Crazy J Rodriguez"
#         value: "DJ Crazy J Rodriguez"
#         value: "DJ Crazy J Rodriguez"
#         value: "Fat Joe"
#         value: "Logic"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_seed_track"
#     value {
#       bytes_list {
#         value: "Logic"
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_can"
#     value {
#       float_list {
#         value: 82.0
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_pl"
#     value {
#       float_list {
#         value: 66.0
#         value: 73.0
#         value: 78.0
#         value: 78.0
#         value: 70.0
#         value: 81.0
#         value: 84.0
#         value: 87.0
#         value: 82.0
#         value: 76.0
#         value: 84.0
#         value: 76.0
#         value: 84.0
#         value: 87.0
#         value: 80.0
#         value: 76.0
#         value: 88.0
#         value: 91.0
#         value: 98.0
#         value: 95.0
#         value: 96.0
#         value: 85.0
#         value: 87.0
#         value: 78.0
#         value: 78.0
#         value: 69.0
#         value: 90.0
#         value: 51.0
#         value: 80.0
#         value: 86.0
#         value: 86.0
#         value: 86.0
#         value: 98.0
#         value: 98.0
#         value: 55.0
#         value: 3.0
#         value: 3.0
#         value: 3.0
#         value: 73.0
#         value: 82.0
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_seed_track"
#     value {
#       float_list {
#         value: 82.0
#       }
#     }
#   }
#   feature {
#     key: "artist_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:artist:4xRYI6VqpkE3UwrDrAZL8L"
#       }
#     }
#   }
#   feature {
#     key: "artist_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:artist:4xRYI6VqpkE3UwrDrAZL8L"
#       }
#     }
#   }
#   feature {
#     key: "artists_followers_pl"
#     value {
#       float_list {
#         value: 1309442.0
#         value: 2810729.0
#         value: 6797299.0
#         value: 6797299.0
#         value: 1593193.0
#         value: 15448013.0
#         value: 9435405.0
#         value: 16510038.0
#         value: 5547634.0
#         value: 6471068.0
#         value: 7940805.0
#         value: 1924131.0
#         value: 7940805.0
#         value: 16510038.0
#         value: 5611842.0
#         value: 6471068.0
#         value: 7133876.0
#         value: 36292264.0
#         value: 62021772.0
#         value: 53731604.0
#         value: 16780344.0
#         value: 18906144.0
#         value: 22589428.0
#         value: 4094997.0
#         value: 1802160.0
#         value: 3346451.0
#         value: 16223653.0
#         value: 44608.0
#         value: 5611842.0
#         value: 6961478.0
#         value: 6961478.0
#         value: 6961478.0
#         value: 62021772.0
#         value: 62021772.0
#         value: 188428.0
#         value: 16293.0
#         value: 16293.0
#         value: 16293.0
#         value: 1282991.0
#         value: 5661726.0
#       }
#     }
#   }
#   feature {
#     key: "collaborative"
#     value {
#       bytes_list {
#         value: "false"
#       }
#     }
#   }
#   feature {
#     key: "description_pl"
#     value {
#       bytes_list {
#         value: ""
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_can"
#     value {
#       float_list {
#         value: 177680.0
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_playlist"
#     value {
#       int64_list {
#         value: 27109459
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_seed_pl"
#     value {
#       float_list {
#         value: 9145375.0
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_songs_pl"
#     value {
#       float_list {
#         value: 208330.0
#         value: 206760.0
#         value: 291893.0
#         value: 206306.0
#         value: 251033.0
#         value: 195840.0
#         value: 319973.0
#         value: 198706.0
#         value: 198293.0
#         value: 231906.0
#         value: 222801.0
#         value: 237300.0
#         value: 239465.0
#         value: 205906.0
#         value: 238320.0
#         value: 197854.0
#         value: 267520.0
#         value: 256533.0
#         value: 257760.0
#         value: 281133.0
#         value: 211000.0
#         value: 208053.0
#         value: 212640.0
#         value: 299960.0
#         value: 189974.0
#         value: 246761.0
#         value: 292986.0
#         value: 270866.0
#         value: 266840.0
#         value: 268004.0
#         value: 222240.0
#         value: 161600.0
#         value: 170637.0
#         value: 173986.0
#         value: 192000.0
#         value: 240169.0
#         value: 222928.0
#         value: 206759.0
#         value: 191900.0
#         value: 182440.0
#       }
#     }
#   }
#   feature {
#     key: "duration_seed_track"
#     value {
#       float_list {
#         value: 182440.0
#       }
#     }
#   }
#   feature {
#     key: "modified_at"
#     value {
#       int64_list {
#         value: 1482537600
#       }
#     }
#   }
#   feature {
#     key: "n_songs_pl"
#     value {
#       float_list {
#         value: 40.0
#       }
#     }
#   }
#   feature {
#     key: "name"
#     value {
#       bytes_list {
#         value: "all music"
#       }
#     }
#   }
#   feature {
#     key: "num_albums_pl"
#     value {
#       float_list {
#         value: 34.0
#       }
#     }
#   }
#   feature {
#     key: "num_artists_pl"
#     value {
#       float_list {
#         value: 29.0
#       }
#     }
#   }
#   feature {
#     key: "pid"
#     value {
#       int64_list {
#         value: 804535
#       }
#     }
#   }
#   feature {
#     key: "pid_pos_id"
#     value {
#       bytes_list {
#         value: "804535-40"
#       }
#     }
#   }
#   feature {
#     key: "pos_can"
#     value {
#       int64_list {
#         value: 40
#       }
#     }
#   }
#   feature {
#     key: "pos_pl"
#     value {
#       int64_list {
#         value: 0
#         value: 1
#         value: 2
#         value: 3
#         value: 4
#         value: 5
#         value: 6
#         value: 7
#         value: 8
#         value: 9
#         value: 10
#         value: 11
#         value: 12
#         value: 13
#         value: 14
#         value: 15
#         value: 16
#         value: 17
#         value: 18
#         value: 19
#         value: 20
#         value: 21
#         value: 22
#         value: 23
#         value: 24
#         value: 25
#         value: 26
#         value: 27
#         value: 28
#         value: 29
#         value: 30
#         value: 31
#         value: 32
#         value: 33
#         value: 34
#         value: 35
#         value: 36
#         value: 37
#         value: 38
#         value: 39
#       }
#     }
#   }
#   feature {
#     key: "pos_seed_track"
#     value {
#       int64_list {
#         value: 39
#       }
#     }
#   }
#   feature {
#     key: "row_number"
#     value {
#       int64_list {
#         value: 1
#       }
#     }
#   }
#   feature {
#     key: "track_name_can"
#     value {
#       bytes_list {
#         value: "Super Mario World"
#       }
#     }
#   }
#   feature {
#     key: "track_name_pl"
#     value {
#       bytes_list {
#         value: "Ghost Town"
#         value: "Be Real"
#         value: "Black Beatles"
#         value: "This Could Be Us"
#         value: "i hate u, i love u (feat. olivia o\'brien)"
#         value: "In the Name of Love"
#         value: "I Know"
#         value: "Hasta el Amanecer"
#         value: "Don\'t"
#         value: "Na Na"
#         value: "Stole the Show"
#         value: "7 Years"
#         value: "Stay"
#         value: "El Perd\303\263n"
#         value: "oui"
#         value: "Slow Motion"
#         value: "Run This Town"
#         value: "White Iverson"
#         value: "Best I Ever Had"
#         value: "When I\'m Gone"
#         value: "Heartless"
#         value: "Don\'t Let Me Down"
#         value: "How Deep Is Your Love"
#         value: "Collard Greens"
#         value: "Ultimate"
#         value: "Panda"
#         value: "No Role Modelz"
#         value: "Move Bitch"
#         value: "Don\'t Tell \'Em"
#         value: "Still D.R.E."
#         value: "Forgot About Dre"
#         value: "The Next Episode"
#         value: "Back To Back"
#         value: "One Dance"
#         value: "Dum Dee Dum"
#         value: "No Handz"
#         value: "The Way We Ball"
#         value: "Cashin\' Out"
#         value: "All The Way Up"
#         value: "A Word From Our Sponsor"
#       }
#     }
#   }
#   feature {
#     key: "track_name_seed_track"
#     value {
#       bytes_list {
#         value: "A Word From Our Sponsor"
#       }
#     }
#   }
#   feature {
#     key: "track_pop_can"
#     value {
#       float_list {
#         value: 57.0
#       }
#     }
#   }
#   feature {
#     key: "track_pop_pl"
#     value {
#       float_list {
#         value: 69.0
#         value: 0.0
#         value: 80.0
#         value: 85.0
#         value: 82.0
#         value: 26.0
#         value: 0.0
#         value: 76.0
#         value: 83.0
#         value: 65.0
#         value: 78.0
#         value: 54.0
#         value: 66.0
#         value: 77.0
#         value: 82.0
#         value: 75.0
#         value: 0.0
#         value: 80.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 46.0
#         value: 80.0
#         value: 84.0
#         value: 71.0
#         value: 0.0
#         value: 64.0
#         value: 62.0
#         value: 79.0
#         value: 1.0
#         value: 0.0
#         value: 1.0
#         value: 71.0
#         value: 2.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 69.0
#         value: 41.0
#       }
#     }
#   }
#   feature {
#     key: "track_pop_seed_track"
#     value {
#       float_list {
#         value: 41.0
#       }
#     }
#   }
#   feature {
#     key: "track_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:track:1py4qzrEEkOvU8uTHYLuOW"
#       }
#     }
#   }
#   feature {
#     key: "track_uri_pl"
#     value {
#       bytes_list {
#         value: "spotify:track:44aN5xKL3kGHvQ5bXVk6B8"
#         value: "spotify:track:32tBNiuuQtkUG5eBWpC0oQ"
#         value: "spotify:track:6fujklziTHa8uoM5OQSfIo"
#         value: "spotify:track:4jTiyLlOJVJj3mCr7yfPQD"
#         value: "spotify:track:7vRriwrloYVaoAe3a9wJHe"
#         value: "spotify:track:04DwTuZ2VBdJCCC5TROn7L"
#         value: "spotify:track:6KQEXfAdNQ85TabNo6mNIk"
#         value: "spotify:track:5Fim1gaXBgsiFfsQAfQSDS"
#         value: "spotify:track:3pXF1nA74528Edde4of9CC"
#         value: "spotify:track:5maiP9UMnTSgoxPX8X3bdz"
#         value: "spotify:track:5masKPHeAOVNgxdLebIcK7"
#         value: "spotify:track:7129iqBafaphfc3WPCGC0L"
#         value: "spotify:track:2FiSTH0GYpIioUgjfzMIja"
#         value: "spotify:track:7qCAVkHWZkF44OzOUKf8Cr"
#         value: "spotify:track:0PJIbOdMs3bd5AT8liULMQ"
#         value: "spotify:track:4NYwy0R3NdvORX2B6OZXBT"
#         value: "spotify:track:6MmT9hje2krkn1twcmtBYu"
#         value: "spotify:track:6eT7xZZlB2mwyzJ2sUKG6w"
#         value: "spotify:track:3fyMH1t6UPeR5croea9PrR"
#         value: "spotify:track:2ye824NM1m7Nc2UPXtwZjL"
#         value: "spotify:track:53gcDgFyqqpvCzXWrnFZpH"
#         value: "spotify:track:0QsvXIfqM0zZoerQfsI9lm"
#         value: "spotify:track:22mek4IiqubGD9ctzxc69s"
#         value: "spotify:track:0zO8ctW0UiuOefR87OeJOZ"
#         value: "spotify:track:6R0GRYk2vs2XuBVemYK5YZ"
#         value: "spotify:track:5OOkp4U9P9oL23maHFHL1h"
#         value: "spotify:track:62vpWI1CHwFy7tMIcSStl8"
#         value: "spotify:track:1Q9b6CeMcDuO0uq5OJCrqu"
#         value: "spotify:track:0Dc7J9VPV4eOInoxUiZrsL"
#         value: "spotify:track:6ltPEsP4edATzvinHOzvk2"
#         value: "spotify:track:0Zh5U48tZNeAzzLTV1CVBE"
#         value: "spotify:track:20LxTsa6936zOlzTWqoPVt"
#         value: "spotify:track:5lFDtgWsjRJu8fPOAyJIAK"
#         value: "spotify:track:1xznGGDReH1oQq0xzbwXa3"
#         value: "spotify:track:4Wxoq8aU3AWcXnuNn3FzOQ"
#         value: "spotify:track:5xynxDkWIaB3nfJ1p5T40w"
#         value: "spotify:track:1c9b9DIFIVCKNARuRbzOJC"
#         value: "spotify:track:5tIbc0813ueWH0tvola7cm"
#         value: "spotify:track:7Ezwtgfw7khBrpvaNPtMoT"
#         value: "spotify:track:1AdD7pFBsQICMHiQTz9uwV"
#       }
#     }
#   }
#   feature {
#     key: "track_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:track:1AdD7pFBsQICMHiQTz9uwV"
#       }
#     }
#   }
# }
#
# features {
#   feature {
#     key: "album_name_can"
#     value {
#       bytes_list {
#         value: "The North Borders"
#       }
#     }
#   }
#   feature {
#     key: "album_name_pl"
#     value {
#       bytes_list {
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Classics"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Mickey Mouse Operation"
#         value: "Awake"
#         value: "Awake"
#         value: "Awake"
#         value: "Awake"
#         value: "Awake"
#         value: "Awake"
#         value: "Awake"
#         value: "Awake"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Sunrise Projector"
#         value: "Past Is Prologue"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Dive"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "Drift"
#         value: "In A Safe Place"
#         value: "In A Safe Place"
#         value: "In A Safe Place"
#         value: "In A Safe Place"
#         value: "In A Safe Place"
#         value: "In A Safe Place"
#         value: "In A Safe Place"
#         value: "In A Safe Place"
#         value: "Black Sands"
#       }
#     }
#   }
#   feature {
#     key: "album_name_seed_track"
#     value {
#       bytes_list {
#         value: "Black Sands"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:album:7sN6lCgPf1rbZYmA3edMKv"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:album:1VlLLqC0tugMgQEUU4K6mq"
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_can"
#     value {
#       float_list {
#         value: 1221147.0
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_seed_track"
#     value {
#       float_list {
#         value: 1221147.0
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_can"
#     value {
#       bytes_list {
#         value: "\'downtempo\', \'electronica\', \'jazztronica\', \'ninja\', \'nu jazz\', \'trip hop\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_pl"
#     value {
#       bytes_list {
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'alternative dance\', \'indietronica\', \'new rave\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'electronica\', \'ninja\', \'trip hop\'"
#         value: "\'chillwave\', \'downtempo\', \'electronica\', \'indietronica\', \'intelligent dance music\'"
#         value: "\'chillwave\', \'downtempo\', \'electronica\', \'indietronica\', \'intelligent dance music\'"
# ...
#         value: "spotify:track:73J0qGlZugpcnD8TPz7sBv"
#         value: "spotify:track:7gXdAqJLCa5aYUeLVxosOz"
#         value: "spotify:track:64sn7wgJfeQKY3Jisnl59w"
#       }
#     }
#   }
#   feature {
#     key: "track_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:track:64sn7wgJfeQKY3Jisnl59w"
#       }
#     }
#   }
# }
#
# features {
#   feature {
#     key: "album_name_can"
#     value {
#       bytes_list {
#         value: "The Stranger (30th Anniversary Legacy Edition)"
#       }
#     }
#   }
#   feature {
#     key: "album_name_pl"
#     value {
#       bytes_list {
#         value: "United"
#         value: "The Stranger (30th Anniversary Legacy Edition)"
#         value: "What A Wonderful World"
#         value: "River Of Dreams"
#         value: "Sinatra/Basie: The Complete Reprise Studio Recordings"
#         value: "Live At The London Palladium"
#         value: "For Once In My Life"
#         value: "Coming Home"
#         value: "A Nickel And A Nail And Ace Of Spades"
#         value: "American Pie"
#         value: "Escape"
#         value: "The Very Thought Of You"
#         value: "Ella & Louis"
#         value: "Reach Out I\'ll Be There"
#         value: "Come Fly With Me"
#         value: "Sinatra/Basie: The Complete Reprise Studio Recordings"
#         value: "Ultimate Sinatra"
#         value: "Pain In My Heart"
#         value: "Rockin\' Robin"
#         value: "Inseparable"
#         value: "Diana Ross Presents The Jackson 5"
#         value: "Song Review: A Greatest Hits Collection"
#         value: "Ray Charles (aka Hallelujah I Love Her So)"
#         value: "Essential"
#         value: "Coming Home"
#         value: "ABC"
#         value: "The Best Of Marvin Gaye"
#         value: "Dean Martin: The Capitol Recordings, Vol. 11 (1960-1961)"
#       }
#     }
#   }
#   feature {
#     key: "album_name_seed_track"
#     value {
#       bytes_list {
#         value: "Dean Martin: The Capitol Recordings, Vol. 11 (1960-1961)"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:album:1Mhn9VosyjtWn4dMPFlna6"
#       }
#     }
#   }
#   feature {
#     key: "album_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:album:3LGVxGRKwi4WfDnhMaBygF"
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_can"
#     value {
#       float_list {
#         value: 4164863.0
#       }
#     }
#   }
#   feature {
#     key: "artist_followers_seed_track"
#     value {
#       float_list {
#         value: 1268154.0
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_can"
#     value {
#       bytes_list {
#         value: "\'classic rock\', \'folk rock\', \'mellow gold\', \'piano rock\', \'rock\', \'singer-songwriter\', \'soft rock\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_pl"
#     value {
#       bytes_list {
#         value: "\'classic soul\', \'funk\', \'indie r&b\', \'motown\', \'northern soul\', \'quiet storm\', \'soul\'"
#         value: "\'classic rock\', \'folk rock\', \'mellow gold\', \'piano rock\', \'rock\', \'singer-songwriter\', \'soft rock\'"
#         value: "\'adult standards\', \'dixieland\', \'harlem renaissance\', \'jazz trumpet\', \'new orleans jazz\', \'swing\', \'vocal jazz\'"
#         value: "\'classic rock\', \'folk rock\', \'mellow gold\', \'piano rock\', \'rock\', \'singer-songwriter\', \'soft rock\'"
#         value: "\'adult standards\', \'easy listening\', \'lounge\'"
#         value: "\'classic soul\', \'funk\', \'indie r&b\', \'motown\', \'northern soul\', \'quiet storm\', \'soul\'"
#         value: "\'adult standards\', \'funk\', \'indie r&b\', \'motown\', \'quiet storm\', \'soul\'"
#         value: "\'modern blues\'"
#         value: "\'classic soul\', \'funk\', \'memphis soul\', \'soul\', \'southern soul\'"
#         value: "\'adult standards\', \'classic rock\', \'folk\', \'folk rock\', \'mellow gold\', \'singer-songwriter\', \'soft rock\'"
#         value: "\'album rock\', \'classic rock\', \'hard rock\', \'mellow gold\', \'rock\', \'soft rock\'"
#         value: "\'adult standards\', \'lounge\', \'vocal jazz\'"
#         value: "\'adult standards\', \'jazz blues\', \'lounge\', \'swing\', \'vocal jazz\'"
#         value: "\'adult standards\', \'brill building pop\', \'classic soul\', \'disco\', \'funk\', \'mellow gold\', \'motown\', \'quiet storm\', \'soul\'"
#         value: "\'adult standards\', \'easy listening\', \'lounge\'"
#         value: "\'adult standards\', \'easy listening\', \'lounge\'"
#         value: "\'adult standards\', \'easy listening\', \'lounge\'"
#         value: "\'classic soul\', \'memphis soul\', \'soul\', \'soul blues\', \'southern soul\'"
#         value: "\'doo-wop\', \'rhythm and blues\', \'rock-and-roll\', \'rockabilly\'"
#         value: "\'adult standards\', \'lounge\', \'mellow gold\', \'neo mellow\', \'quiet storm\', \'soft rock\', \'soul\', \'vocal jazz\'"
#         value: "\'adult standards\', \'motown\', \'soul\'"
#         value: "\'adult standards\', \'funk\', \'indie r&b\', \'motown\', \'quiet storm\', \'soul\'"
#         value: "\'adult standards\', \'classic soul\', \'jazz blues\', \'piano blues\', \'soul\', \'soul blues\', \'vocal jazz\'"
#         value: "\'brill building pop\', \'motown\', \'northern soul\', \'soul\'"
#         value: "\'modern blues\'"
#         value: "\'adult standards\', \'motown\', \'soul\'"
#         value: "\'classic soul\', \'funk\', \'indie r&b\', \'motown\', \'northern soul\', \'quiet storm\', \'soul\'"
#         value: "\'adult standards\', \'easy listening\', \'lounge\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_genres_seed_track"
#     value {
#       bytes_list {
#         value: "\'adult standards\', \'easy listening\', \'lounge\'"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_can"
#     value {
#       bytes_list {
#         value: "Billy Joel"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_pl"
#     value {
#       bytes_list {
#         value: "Marvin Gaye"
#         value: "Billy Joel"
#         value: "Louis Armstrong"
#         value: "Billy Joel"
#         value: "Frank Sinatra"
#         value: "Marvin Gaye"
#         value: "Stevie Wonder"
#         value: "Leon Bridges"
#         value: "O.V. Wright"
#         value: "Don McLean"
#         value: "Journey"
#         value: "Nat King Cole"
#         value: "Ella Fitzgerald"
#         value: "Four Tops"
#         value: "Frank Sinatra"
#         value: "Frank Sinatra"
#         value: "Frank Sinatra"
#         value: "Otis Redding"
#         value: "Bobby Day"
#         value: "Natalie Cole"
#         value: "The Jackson 5"
#         value: "Stevie Wonder"
#         value: "Ray Charles"
#         value: "The Contours"
#         value: "Leon Bridges"
#         value: "The Jackson 5"
#         value: "Marvin Gaye"
#         value: "Dean Martin"
#       }
#     }
#   }
#   feature {
#     key: "artist_name_seed_track"
#     value {
#       bytes_list {
#         value: "Dean Martin"
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_can"
#     value {
#       float_list {
#         value: 80.0
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_pl"
#     value {
#       float_list {
#         value: 76.0
#         value: 80.0
#         value: 73.0
#         value: 80.0
#         value: 79.0
#         value: 76.0
#         value: 79.0
#         value: 77.0
#         value: 42.0
#         value: 67.0
#         value: 76.0
#         value: 71.0
#         value: 71.0
#         value: 66.0
#         value: 79.0
#         value: 79.0
#         value: 79.0
#         value: 72.0
#         value: 50.0
#         value: 66.0
#         value: 70.0
#         value: 79.0
#         value: 70.0
#         value: 54.0
#         value: 77.0
#         value: 70.0
#         value: 76.0
#         value: 71.0
#       }
#     }
#   }
#   feature {
#     key: "artist_pop_seed_track"
#     value {
#       float_list {
#         value: 71.0
#       }
#     }
#   }
#   feature {
#     key: "artist_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:artist:6zFYqv1mOsgBRQbae3JJ9e"
#       }
#     }
#   }
#   feature {
#     key: "artist_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:artist:49e4v89VmlDcFCMyDv9wQ9"
#       }
#     }
#   }
#   feature {
#     key: "artists_followers_pl"
#     value {
#       float_list {
#         value: 4501613.0
#         value: 4164863.0
#         value: 2469907.0
#         value: 4164863.0
#         value: 5454378.0
#         value: 4501613.0
#         value: 5543452.0
#         value: 1371518.0
#         value: 33451.0
#         value: 727774.0
#         value: 4178141.0
#         value: 1793668.0
#         value: 2140368.0
#         value: 887844.0
#         value: 5454378.0
#         value: 5454378.0
#         value: 5454378.0
#         value: 1906832.0
#         value: 19423.0
#         value: 493281.0
#         value: 1230171.0
#         value: 5543452.0
#         value: 1856084.0
#         value: 102978.0
#         value: 1371518.0
#         value: 1230171.0
#         value: 4501613.0
#         value: 1268154.0
#       }
#     }
#   }
#   feature {
#     key: "collaborative"
#     value {
#       bytes_list {
#         value: "false"
#       }
#     }
#   }
#   feature {
#     key: "description_pl"
#     value {
#       bytes_list {
#         value: ""
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_can"
#     value {
#       float_list {
#         value: 210760.0
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_playlist"
#     value {
#       int64_list {
#         value: 6949031
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_seed_pl"
#     value {
#       float_list {
#         value: 6111978.0
#       }
#     }
#   }
#   feature {
#     key: "duration_ms_songs_pl"
#     value {
#       float_list {
#         value: 151666.0
#         value: 235560.0
#         value: 139226.0
#         value: 247626.0
#         value: 147000.0
#         value: 712666.0
#         value: 170600.0
#         value: 140133.0
#         value: 133506.0
#         value: 516893.0
#         value: 250986.0
#         value: 195853.0
#         value: 340133.0
#         value: 162960.0
#         value: 199093.0
#         value: 147000.0
#         value: 201200.0
#         value: 172333.0
#         value: 160080.0
#         value: 171960.0
#         value: 176333.0
#         value: 239120.0
#         value: 171466.0
#         value: 174400.0
#         value: 183333.0
#         value: 174866.0
#         value: 248693.0
#         value: 147293.0
#       }
#     }
#   }
#   feature {
#     key: "duration_seed_track"
#     value {
#       float_list {
#         value: 147293.0
#       }
#     }
#   }
#   feature {
#     key: "modified_at"
#     value {
#       int64_list {
#         value: 1506729600
#       }
#     }
#   }
#   feature {
#     key: "n_songs_pl"
#     value {
#       float_list {
#         value: 28.0
#       }
#     }
#   }
#   feature {
#     key: "name"
#     value {
#       bytes_list {
#         value: "Feel Good"
#       }
#     }
#   }
#   feature {
#     key: "num_albums_pl"
#     value {
#       float_list {
#         value: 26.0
#       }
#     }
#   }
#   feature {
#     key: "num_artists_pl"
#     value {
#       float_list {
#         value: 19.0
#       }
#     }
#   }
#   feature {
#     key: "pid"
#     value {
#       int64_list {
#         value: 251051
#       }
#     }
#   }
#   feature {
#     key: "pid_pos_id"
#     value {
#       bytes_list {
#         value: "251051-28"
#       }
#     }
#   }
#   feature {
#     key: "pos_can"
#     value {
#       int64_list {
#         value: 28
#       }
#     }
#   }
#   feature {
#     key: "pos_pl"
#     value {
#       int64_list {
#         value: 0
#         value: 1
#         value: 2
#         value: 3
#         value: 4
#         value: 5
#         value: 6
#         value: 7
#         value: 8
#         value: 9
#         value: 10
#         value: 11
#         value: 12
#         value: 13
#         value: 14
#         value: 15
#         value: 16
#         value: 17
#         value: 18
#         value: 19
#         value: 20
#         value: 21
#         value: 22
#         value: 23
#         value: 24
#         value: 25
#         value: 26
#         value: 27
#       }
#     }
#   }
#   feature {
#     key: "pos_seed_track"
#     value {
#       int64_list {
#         value: 27
#       }
#     }
#   }
#   feature {
#     key: "row_number"
#     value {
#       int64_list {
#         value: 1
#       }
#     }
#   }
#   feature {
#     key: "track_name_can"
#     value {
#       bytes_list {
#         value: "Movin\' Out (Anthony\'s Song)"
#       }
#     }
#   }
#   feature {
#     key: "track_name_pl"
#     value {
#       bytes_list {
#         value: "Ain\'t No Mountain High Enough"
#         value: "Only the Good Die Young"
#         value: "What A Wonderful World - Single Version"
#         value: "The River of Dreams"
#         value: "Fly Me To The Moon"
#         value: "Got To Give It Up"
#         value: "For Once In My Life"
#         value: "Better Man"
#         value: "Ace Of Spades"
#         value: "American Pie"
#         value: "Don\'t Stop Believin\'"
#         value: "For All We Know"
#         value: "The Nearness Of You"
#         value: "I Can\'t Help Myself (Sugar Pie, Honey Bunch) - Album Version (Stereo)"
#         value: "Come Fly With Me - 1998 Digital Remaster"
#         value: "Fly Me To The Moon"
#         value: "The Way You Look Tonight"
#         value: "Stand By Me"
#         value: "Rockin\' Robin"
#         value: "This Will Be (An Everlasting Love)"
#         value: "I Want You Back"
#         value: "Superstition - Single Version"
#         value: "I\'ve Got A Woman"
#         value: "Do You Love Me - Single Version (Mono)"
#         value: "Smooth Sailin\'"
#         value: "ABC"
#         value: "Got To Give It Up (Part 1)"
#         value: "Ain\'t That A Kick In The Head"
#       }
#     }
#   }
#   feature {
#     key: "track_name_seed_track"
#     value {
#       bytes_list {
#         value: "Ain\'t That A Kick In The Head"
#       }
#     }
#   }
#   feature {
#     key: "track_pop_can"
#     value {
#       float_list {
#         value: 68.0
#       }
#     }
#   }
#   feature {
#     key: "track_pop_pl"
#     value {
#       float_list {
#         value: 0.0
#         value: 71.0
#         value: 72.0
#         value: 67.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 40.0
#         value: 80.0
#         value: 85.0
#         value: 27.0
#         value: 0.0
#         value: 0.0
#         value: 70.0
#         value: 0.0
#         value: 0.0
#         value: 71.0
#         value: 65.0
#         value: 75.0
#         value: 0.0
#         value: 0.0
#         value: 70.0
#         value: 49.0
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 64.0
#       }
#     }
#   }
#   feature {
#     key: "track_pop_seed_track"
#     value {
#       float_list {
#         value: 64.0
#       }
#     }
#   }
#   feature {
#     key: "track_uri_can"
#     value {
#       bytes_list {
#         value: "spotify:track:16GUMo6u3D2qo9a19AkYct"
#       }
#     }
#   }
#   feature {
#     key: "track_uri_pl"
#     value {
#       bytes_list {
#         value: "spotify:track:2H3ZUSE54pST4ubRd5FzFR"
#         value: "spotify:track:1xOXXYh6lTW8laxlW7JP2J"
#         value: "spotify:track:29U7stRjqHU6rMiS8BfaI9"
#         value: "spotify:track:30qVCFYKBtAENjTIBA8FPZ"
#         value: "spotify:track:2y8Eez5cFFf2JzD546LThM"
#         value: "spotify:track:1cQBO3VJxv6RWmCsB5KSOI"
#         value: "spotify:track:2yNWwardt8VzlpNBWrGYD6"
#         value: "spotify:track:3kguMbJma0qhOLniGsFlKq"
#         value: "spotify:track:0xReSyPY2NLLQmhIPSvmfD"
#         value: "spotify:track:1fDsrQ23eTAVFElUMaf38X"
#         value: "spotify:track:4bHsxqR3GMrXTxEPLuK5ue"
#         value: "spotify:track:4vBDDMzwc7DpSgFDjUU14G"
#         value: "spotify:track:1O8jVjF78N1gXmU7CGoryX"
#         value: "spotify:track:1I8956VUImfafRIuccR9Cq"
#         value: "spotify:track:4hHbeIIKO5Y5uLyIEbY9Gn"
#         value: "spotify:track:2y8Eez5cFFf2JzD546LThM"
#         value: "spotify:track:4pV1bl7OiFW4mMNLmsgQGC"
#         value: "spotify:track:1aj4GXfmEYXfdVZohCpNKu"
#         value: "spotify:track:4FlYcJnfkeBpowEHJ72Bmt"
#         value: "spotify:track:0PDCewmZCp0P5s00bptcdd"
#         value: "spotify:track:3b0EOvScbZUc0qJx0E1L2z"
#         value: "spotify:track:5lXcSvHRVjQJ3LB2rLKQog"
#         value: "spotify:track:2xar08Fq5xra2KKZs5Bw9j"
#         value: "spotify:track:298jnAsgLcTRkRP5TKB7Mj"
#         value: "spotify:track:3JbqwFY5q0ORO3siv5zL3A"
#         value: "spotify:track:6cb0HzFQPN4BGADOmSzPCw"
#         value: "spotify:track:5n1A3VxqT4VcNez4Ah6dSu"
#         value: "spotify:track:7fQ3PYTYdu208fQ3JEm2U7"
#       }
#     }
#   }
#   feature {
#     key: "track_uri_seed_track"
#     value {
#       bytes_list {
#         value: "spotify:track:7fQ3PYTYdu208fQ3JEm2U7"
#       }
#     }
#   }
# }
